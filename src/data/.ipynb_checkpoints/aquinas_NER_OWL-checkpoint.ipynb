# %% [markdown]
# # Goals of this notebook
#
# 1. Named Entity Recognition of the summa
# 2. Build Ontology of the summa

# %%
import json
with open("aquinas.json", "r") as handle:
    data = json.load(handle)
    
data[:5]
# Out:
# [{'volume': 'Volume 1',
#   'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#   'question': 'Question 1.',
#   'articleTitle': 'Article 1. Whether, besides philosophy, any further doctrine is required?',
#   'article': 'Article 1.',
#   'articleObjection': ['Objection 1. It seems that, besides philosophical science, we have no need of any further knowledge. For man should not seek to know what is above reason: "Seek not the things that are too high for thee" (Sirach 3:22). But whatever is not above reason is fully treated of in philosophical science. Therefore any other knowledge besides philosophical science is superfluous.',
#    'Objection 2. Further, knowledge can be concerned only with being, for nothing can be known, save what is true; and all that is, is true. But everything that is, is treated of in philosophical science—even God Himself; so that there is a part of philosophy called theology, or the divine science, as Aristotle has proved (Metaph. vi). Therefore, besides philosophical science, there is no need of any further knowledge.'],
#   'articleBody': ['On the contrary, It is written (2 Timothy 3:16): "All Scripture, inspired of God is profitable to teach, to reprove, to correct, to instruct in justice." Now Scripture, inspired of God, is no part of philosophical science, which has been built up by human reason. Therefore it is useful that besides philosophical science, there should be other knowledge, i.e. inspired of God.',
#    'I answer that, It was necessary for man\'s salvation that there should be a knowledge revealed by God besides philosophical science built up by human reason. Firstly, indeed, because man is directed to God, as to an end that surpasses the grasp of his reason: "The eye hath not seen, O God, besides Thee, what things Thou hast prepared for them that wait for Thee" (Isaiah 64:4). But the end must first be known by men who are to direct their thoughts and actions to the end. Hence it was necessary for the salvation of man that certain truths which exceed human reason should be made known to him by divine revelation. Even as regards those truths about God which human reason could have discovered, it was necessary that man should be taught by a divine revelation; because the truth about God such as reason could discover, would only be known by a few, and that after a long time, and with the admixture of many errors. Whereas man\'s whole salvation, which is in God, depends upon the knowledge of this truth. Therefore, in order that the salvation of men might be brought about more fitly and more surely, it was necessary that they should be taught divine truths by divine revelation. It was therefore necessary that besides philosophical science built up by reason, there should be a sacred science learned through revelation.'],
#   'articleReplyToObjections': ['Reply to Objection 1. Although those things which are beyond man\'s knowledge may not be sought for by man through his reason, nevertheless, once they are revealed by God, they must be accepted by faith. Hence the sacred text continues, "For many things are shown to thee above the understanding of man" (Sirach 3:25). And in this, the sacred science consists.',
#    'Reply to Objection 2. Sciences are differentiated according to the various means through which knowledge is obtained. For the astronomer and the physicist both may prove the same conclusion: that the earth, for instance, is round: the astronomer by means of mathematics (i.e. abstracting from matter), but the physicist by means of matter itself. Hence there is no reason why those things which may be learned from philosophical science, so far as they can be known by natural reason, may not also be taught us by another science so far as they fall within revelation. Hence theology included in sacred doctrine differs in kind from that theology which is part of philosophy.']},
#  {'volume': 'Volume 1',
#   'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#   'question': 'Question 1.',
#   'articleTitle': 'Article 2. Whether sacred doctrine is a science?',
#   'article': 'Article 2.',
#   'articleObjection': ['Objection 1. It seems that sacred doctrine is not a science. For every science proceeds from self-evident principles. But sacred doctrine proceeds from articles of faith which are not self-evident, since their truth is not admitted by all: "For all men have not faith" (2 Thessalonians 3:2). Therefore sacred doctrine is not a science.',
#    'Objection 2. Further, no science deals with individual facts. But this sacred science treats of individual facts, such as the deeds of Abraham, Isaac and Jacob and such like. Therefore sacred doctrine is not a science.'],
#   'articleBody': ['On the contrary, Augustine says (De Trin. xiv, 1) "to this science alone belongs that whereby saving faith is begotten, nourished, protected and strengthened." But this can be said of no science except sacred doctrine. Therefore sacred doctrine is a science.',
#    'I answer that, Sacred doctrine is a science. We must bear in mind that there are two kinds of sciences. There are some which proceed from a principle known by the natural light of intelligence, such as arithmetic and geometry and the like. There are some which proceed from principles known by the light of a higher science: thus the science of perspective proceeds from principles established by geometry, and music from principles established by arithmetic. So it is that sacred doctrine is a science because it proceeds from principles established by the light of a higher science, namely, the science of God and the blessed. Hence, just as the musician accepts on authority the principles taught him by the mathematician, so sacred science is established on principles revealed by God.'],
#   'articleReplyToObjections': ['Reply to Objection 1. The principles of any science are either in themselves self-evident, or reducible to the conclusions of a higher science; and such, as we have said, are the principles of sacred doctrine.',
#    'Reply to Objection 2. Individual facts are treated of in sacred doctrine, not because it is concerned with them principally, but they are introduced rather both as examples to be followed in our lives (as in moral sciences) and in order to establish the authority of those men through whom the divine revelation, on which this sacred scripture or doctrine is based, has come down to us.']},
#  {'volume': 'Volume 1',
#   'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#   'question': 'Question 1.',
#   'articleTitle': 'Article 3. Whether sacred doctrine is one science?',
#   'article': 'Article 3.',
#   'articleObjection': ['Objection 1. It seems that sacred doctrine is not one science; for according to the Philosopher (Poster. i) "that science is one which treats only of one class of subjects." But the creator and the creature, both of whom are treated of in sacred doctrine, cannot be grouped together under one class of subjects. Therefore sacred doctrine is not one science.',
#    'Objection 2. Further, in sacred doctrine we treat of angels, corporeal creatures and human morality. But these belong to separate philosophical sciences. Therefore sacred doctrine cannot be one science.'],
#   'articleBody': ['On the contrary, Holy Scripture speaks of it as one science: "Wisdom gave him the knowledge [scientiam] of holy things" (Wisdom 10:10).',
#    'I answer that, Sacred doctrine is one science. The unity of a faculty or habit is to be gauged by its object, not indeed, in its material aspect, but as regards the precise formality under which it is an object. For example, man, ass, stone agree in the one precise formality of being colored; and color is the formal object of sight. Therefore, because Sacred Scripture considers things precisely under the formality of being divinely revealed, whatever has been divinely revealed possesses the one precise formality of the object of this science; and therefore is included under sacred doctrine as under one science.'],
#   'articleReplyToObjections': ['Reply to Objection 1. Sacred doctrine does not treat of God and creatures equally, but of God primarily, and of creatures only so far as they are referable to God as their beginning or end. Hence the unity of this science is not impaired.',
#    'Reply to Objection 2. Nothing prevents inferior faculties or habits from being differentiated by something which falls under a higher faculty or habit as well; because the higher faculty or habit regards the object in its more universal formality, as the object of the "common sense" is whatever affects the senses, including, therefore, whatever is visible or audible. Hence the "common sense", although one faculty, extends to all the objects of the five senses. Similarly, objects which are the subject-matter of different philosophical sciences can yet be treated of by this one single sacred science under one aspect precisely so far as they can be included in revelation. So that in this way, sacred doctrine bears, as it were, the stamp of the divine science which is one and simple, yet extends to everything.']},
#  {'volume': 'Volume 1',
#   'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#   'question': 'Question 1.',
#   'articleTitle': 'Article 4. Whether sacred doctrine is a practical science?',
#   'article': 'Article 4.',
#   'articleObjection': ['Objection 1. It seems that sacred doctrine is a practical science; for a practical science is that which ends in action according to the Philosopher (Metaph. ii). But sacred doctrine is ordained to action: "Be ye doers of the word, and not hearers only" (James 1:22). Therefore sacred doctrine is a practical science.',
#    'Objection 2. Further, sacred doctrine is divided into the Old and the New Law. But law implies a moral science which is a practical science. Therefore sacred doctrine is a practical science.'],
#   'articleBody': ['On the contrary, Every practical science is concerned with human operations; as moral science is concerned with human acts, and architecture with buildings. But sacred doctrine is chiefly concerned with God, whose handiwork is especially man. Therefore it is not a practical but a speculative science.',
#    'I answer that, Sacred doctrine, being one, extends to things which belong to different philosophical sciences because it considers in each the same formal aspect, namely, so far as they can be known through divine revelation. Hence, although among the philosophical sciences one is speculative and another practical, nevertheless sacred doctrine includes both; as God, by one and the same science, knows both Himself and His works. Still, it is speculative rather than practical because it is more concerned with divine things than with human acts; though it does treat even of these latter, inasmuch as man is ordained by them to the perfect knowledge of God in which consists eternal bliss. This is a sufficient answer to the Objections.'],
#   'articleReplyToObjections': []},
#  {'volume': 'Volume 1',
#   'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#   'question': 'Question 1.',
#   'articleTitle': 'Article 5. Whether sacred doctrine is nobler than other sciences?',
#   'article': 'Article 5.',
#   'articleObjection': ['Objection 1. It seems that sacred doctrine is not nobler than other sciences; for the nobility of a science depends on the certitude it establishes. But other sciences, the principles of which cannot be doubted, seem to be more certain than sacred doctrine; for its principles — namely, articles of faith — can be doubted. Therefore other sciences seem to be nobler.',
#    'Objection 2. Further, it is the sign of a lower science to depend upon a higher; as music depends on arithmetic. But sacred doctrine does in a sense depend upon philosophical sciences; for Jerome observes, in his Epistle to Magnus, that "the ancient doctors so enriched their books with the ideas and phrases of the philosophers, that thou knowest not what more to admire in them, their profane erudition or their scriptural learning." Therefore sacred doctrine is inferior to other sciences.'],
#   'articleBody': ['On the contrary, Other sciences are called the handmaidens of this one: "Wisdom sent her maids to invite to the tower" (Proverbs 9:3).',
#    "I answer that, Since this science is partly speculative and partly practical, it transcends all others speculative and practical. Now one speculative science is said to be nobler than another, either by reason of its greater certitude, or by reason of the higher worth of its subject-matter. In both these respects this science surpasses other speculative sciences; in point of greater certitude, because other sciences derive their certitude from the natural light of human reason, which can err; whereas this derives its certitude from the light of divine knowledge, which cannot be misled: in point of the higher worth of its subject-matter because this science treats chiefly of those things which by their sublimity transcend human reason; while other sciences consider only those things which are within reason's grasp. Of the practical sciences, that one is nobler which is ordained to a further purpose, as political science is nobler than military science; for the good of the army is directed to the good of the State. But the purpose of this science, in so far as it is practical, is eternal bliss; to which as to an ultimate end the purposes of every practical science are directed. Hence it is clear that from every standpoint, it is nobler than other sciences."],
#   'articleReplyToObjections': ['Reply to Objection 1. It may well happen that what is in itself the more certain may seem to us the less certain on account of the weakness of our intelligence, "which is dazzled by the clearest objects of nature; as the owl is dazzled by the light of the sun" (Metaph. ii, lect. i). Hence the fact that some happen to doubt about articles of faith is not due to the uncertain nature of the truths, but to the weakness of human intelligence; yet the slenderest knowledge that may be obtained of the highest things is more desirable than the most certain knowledge obtained of lesser things, as is said in de Animalibus xi.',
#    'Reply to Objection 2. This science can in a sense depend upon the philosophical sciences, not as though it stood in need of them, but only in order to make its teaching clearer. For it accepts its principles not from other sciences, but immediately from God, by revelation. Therefore it does not depend upon other sciences as upon the higher, but makes use of them as of the lesser, and as handmaidens: even so the master sciences make use of the sciences that supply their materials, as political of military science. That it thus uses them is not due to its own defect or insufficiency, but to the defect of our intelligence, which is more easily led by what is known through natural reason (from which proceed the other sciences) to that which is above reason, such as are the teachings of this science.']}]

# %%
def getCorpusContent(data):
    articles = []
    for chunk in data:
        text = ""
        volume = chunk["volume"]
        question = chunk["question"]
        article = chunk["article"]
        for i in chunk["articleBody"]:
            text += i
            text += "\n"
        articles.append({"volume":volume, "question":question, "article":article, "data":text})
    return articles

corpus = getCorpusContent(data)
corpus[0]
# Out:
# {'volume': 'Volume 1',
#  'question': 'Question 1.',
#  'article': 'Article 1.',
#  'data': 'On the contrary, It is written (2 Timothy 3:16): "All Scripture, inspired of God is profitable to teach, to reprove, to correct, to instruct in justice." Now Scripture, inspired of God, is no part of philosophical science, which has been built up by human reason. Therefore it is useful that besides philosophical science, there should be other knowledge, i.e. inspired of God.\nI answer that, It was necessary for man\'s salvation that there should be a knowledge revealed by God besides philosophical science built up by human reason. Firstly, indeed, because man is directed to God, as to an end that surpasses the grasp of his reason: "The eye hath not seen, O God, besides Thee, what things Thou hast prepared for them that wait for Thee" (Isaiah 64:4). But the end must first be known by men who are to direct their thoughts and actions to the end. Hence it was necessary for the salvation of man that certain truths which exceed human reason should be made known to him by divine revelation. Even as regards those truths about God which human reason could have discovered, it was necessary that man should be taught by a divine revelation; because the truth about God such as reason could discover, would only be known by a few, and that after a long time, and with the admixture of many errors. Whereas man\'s whole salvation, which is in God, depends upon the knowledge of this truth. Therefore, in order that the salvation of men might be brought about more fitly and more surely, it was necessary that they should be taught divine truths by divine revelation. It was therefore necessary that besides philosophical science built up by reason, there should be a sacred science learned through revelation.\n'}

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

for i, c in enumerate(corpus):
    doc = nlp(c["data"])
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.is_stop)
    break
# Out:
# On on ADP IN prep True
# the the DET DT det True
# contrary contrary NOUN NN pobj False
# , , PUNCT , punct False
# It -PRON- PRON PRP nsubjpass True
# is be AUX VBZ auxpass True
# written write VERB VBN ROOT False
# ( ( PUNCT -LRB- punct False
# 2 2 NUM CD nummod False
# Timothy Timothy PROPN NNP npadvmod False
# 3:16 3:16 NUM CD nummod False
# ) ) PUNCT -RRB- punct False
# : : PUNCT : punct False
# " " PUNCT `` punct False
# All all DET DT det True
# Scripture Scripture PROPN NNP nsubj False
# , , PUNCT , punct False
# inspired inspire VERB VBN advcl False
# of of ADP IN prep True
# God God PROPN NNP pobj False
# is be AUX VBZ ccomp True
# profitable profitable ADJ JJ acomp False
# to to PART TO aux True
# teach teach VERB VB xcomp False
# , , PUNCT , punct False
# to to PART TO aux True
# reprove reprove VERB VB xcomp False
# , , PUNCT , punct False
# to to PART TO aux True
# correct correct VERB VB xcomp False
# , , PUNCT , punct False
# to to PART TO aux True
# instruct instruct VERB VB xcomp False
# in in ADP IN prep True
# justice justice NOUN NN pobj False
# . . PUNCT . punct False
# " " PUNCT '' punct False
# Now now ADV RB advmod True
# Scripture Scripture PROPN NNP nsubj False
# , , PUNCT , punct False
# inspired inspire VERB VBN acl False
# of of ADP IN prep True
# God God PROPN NNP pobj False
# , , PUNCT , punct False
# is be AUX VBZ ROOT True
# no no DET DT det True
# part part NOUN NN attr True
# of of ADP IN prep True
# philosophical philosophical ADJ JJ amod False
# science science NOUN NN pobj False
# , , PUNCT , punct False
# which which DET WDT nsubjpass True
# has have AUX VBZ aux True
# been be AUX VBN auxpass True
# built build VERB VBN relcl False
# up up ADP RP prt True
# by by ADP IN agent True
# human human ADJ JJ amod False
# reason reason NOUN NN pobj False
# . . PUNCT . punct False
# Therefore therefore ADV RB advmod True
# it -PRON- PRON PRP nsubj True
# is be AUX VBZ ROOT True
# useful useful ADJ JJ acomp False
# that that SCONJ IN mark True
# besides besides SCONJ IN prep True
# philosophical philosophical ADJ JJ amod False
# science science NOUN NN pobj False
# , , PUNCT , punct False
# there there PRON EX expl True
# should should VERB MD aux True
# be be AUX VB ccomp True
# other other ADJ JJ amod True
# knowledge knowledge NOUN NN attr False
# , , PUNCT , punct False
# i.e. i.e. X FW advmod False
# inspired inspire VERB VBN acomp False
# of of ADP IN prep True
# God God PROPN NNP pobj False
# . . PUNCT . punct False
#
#
#  SPACE _SP  False
# I -PRON- PRON PRP nsubj True
# answer answer VERB VBP ROOT False
# that that DET DT dobj True
# , , PUNCT , punct False
# It -PRON- PRON PRP nsubj True
# was be AUX VBD ROOT True
# necessary necessary ADJ JJ acomp False
# for for ADP IN prep True
# man man NOUN NN poss False
# 's 's PART POS case True
# salvation salvation NOUN NN pobj False
# that that SCONJ IN mark True
# there there PRON EX expl True
# should should VERB MD aux True
# be be AUX VB ccomp True
# a a DET DT det True
# knowledge knowledge NOUN NN attr False
# revealed reveal VERB VBN acl False
# by by ADP IN agent True
# God God PROPN NNP pobj False
# besides besides SCONJ IN prep True
# philosophical philosophical ADJ JJ amod False
# science science NOUN NN pobj False
# built build VERB VBN acl False
# up up ADP RP prt True
# by by ADP IN agent True
# human human ADJ JJ amod False
# reason reason NOUN NN pobj False
# . . PUNCT . punct False
# Firstly firstly ADV RB advmod False
# , , PUNCT , punct False
# indeed indeed ADV RB advmod True
# , , PUNCT , punct False
# because because SCONJ IN mark True
# man man NOUN NN nsubjpass False
# is be AUX VBZ auxpass True
# directed direct VERB VBN advcl False
# to to ADP IN prep True
# God God PROPN NNP pobj False
# , , PUNCT , punct False
# as as SCONJ IN prep True
# to to ADP IN prep True
# an an DET DT det True
# end end NOUN NN pobj False
# that that DET WDT nsubj True
# surpasses surpass VERB VBZ relcl False
# the the DET DT det True
# grasp grasp NOUN NN dobj False
# of of ADP IN prep True
# his -PRON- DET PRP$ poss True
# reason reason NOUN NN pobj False
# : : PUNCT : punct False
# " " PUNCT `` punct False
# The the DET DT det True
# eye eye NOUN NN compound False
# hath hath NOUN NN nsubj False
# not not PART RB neg True
# seen see VERB VBN ROOT False
# , , PUNCT , punct False
# O o INTJ UH intj False
# God God PROPN NNP npadvmod False
# , , PUNCT , punct False
# besides besides SCONJ IN prep True
# Thee Thee PROPN NNP pobj False
# , , PUNCT , punct False
# what what PRON WP det True
# things thing NOUN NNS dobj False
# Thou Thou PROPN NNP nsubj False
# hast hast NOUN NN nsubj False
# prepared prepare VERB VBD ccomp False
# for for ADP IN dative True
# them -PRON- PRON PRP pobj True
# that that DET WDT nsubj True
# wait wait VERB VBP ccomp False
# for for ADP IN prep True
# Thee Thee PROPN NNP pobj False
# " " PUNCT '' punct False
# ( ( PUNCT -LRB- punct False
# Isaiah Isaiah PROPN NNP npadvmod False
# 64:4 64:4 PROPN NNP nummod False
# ) ) PUNCT -RRB- punct False
# . . PUNCT . punct False
# But but CCONJ CC cc True
# the the DET DT det True
# end end NOUN NN nsubjpass False
# must must VERB MD aux True
# first first ADV RB advmod True
# be be AUX VB auxpass True
# known know VERB VBN ROOT False
# by by ADP IN agent True
# men man NOUN NNS pobj False
# who who PRON WP nsubj True
# are be AUX VBP relcl True
# to to PART TO aux True
# direct direct VERB VB xcomp False
# their -PRON- DET PRP$ poss True
# thoughts thought NOUN NNS dobj False
# and and CCONJ CC cc True
# actions action NOUN NNS conj False
# to to ADP IN prep True
# the the DET DT det True
# end end NOUN NN pobj False
# . . PUNCT . punct False
# Hence hence ADV RB advmod True
# it -PRON- PRON PRP nsubj True
# was be AUX VBD ROOT True
# necessary necessary ADJ JJ acomp False
# for for ADP IN prep True
# the the DET DT det True
# salvation salvation NOUN NN pobj False
# of of ADP IN prep True
# man man NOUN NN pobj False
# that that SCONJ IN mark True
# certain certain ADJ JJ amod False
# truths truth NOUN NNS nsubjpass False
# which which DET WDT nsubj True
# exceed exceed VERB VBP relcl False
# human human ADJ JJ amod False
# reason reason NOUN NN dobj False
# should should VERB MD aux True
# be be AUX VB auxpass True
# made make VERB VBN acl True
# known known ADJ JJ oprd False
# to to ADP IN prep True
# him -PRON- PRON PRP pobj True
# by by ADP IN agent True
# divine divine ADJ JJ amod False
# revelation revelation NOUN NN pobj False
# . . PUNCT . punct False
# Even even ADV RB advmod True
# as as SCONJ IN mark True
# regards regard VERB VBZ advcl False
# those those DET DT det True
# truths truth NOUN NNS dobj False
# about about ADP IN prep True
# God God PROPN NNP pobj False
# which which DET WDT dobj True
# human human ADJ JJ amod False
# reason reason NOUN NN nsubj False
# could could VERB MD aux True
# have have AUX VB aux True
# discovered discover VERB VBN relcl False
# , , PUNCT , punct False
# it -PRON- PRON PRP nsubj True
# was be AUX VBD ROOT True
# necessary necessary ADJ JJ acomp False
# that that DET DT mark True
# man man NOUN NN nsubjpass False
# should should VERB MD aux True
# be be AUX VB auxpass True
# taught teach VERB VBN ccomp False
# by by ADP IN agent True
# a a DET DT det True
# divine divine ADJ JJ amod False
# revelation revelation NOUN NN pobj False
# ; ; PUNCT : punct False
# because because SCONJ IN mark True
# the the DET DT det True
# truth truth NOUN NN nsubj False
# about about ADP IN prep True
# God God PROPN NNP pobj False
# such such ADJ JJ amod True
# as as SCONJ IN prep True
# reason reason NOUN NN pobj False
# could could VERB MD aux True
# discover discover VERB VB advcl False
# , , PUNCT , punct False
# would would VERB MD aux True
# only only ADV RB advmod True
# be be AUX VB auxpass True
# known know VERB VBN conj False
# by by ADP IN agent True
# a a DET DT det True
# few few ADJ JJ pobj True
# , , PUNCT , punct False
# and and CCONJ CC cc True
# that that SCONJ IN conj True
# after after ADP IN prep True
# a a DET DT det True
# long long ADJ JJ amod False
# time time NOUN NN pobj False
# , , PUNCT , punct False
# and and CCONJ CC cc True
# with with ADP IN conj True
# the the DET DT det True
# admixture admixture NOUN NN pobj False
# of of ADP IN prep True
# many many ADJ JJ amod True
# errors error NOUN NNS pobj False
# . . PUNCT . punct False
# Whereas whereas SCONJ IN mark True
# man man NOUN NN poss False
# 's 's PART POS case True
# whole whole ADJ JJ amod True
# salvation salvation NOUN NN nsubj False
# , , PUNCT , punct False
# which which DET WDT nsubj True
# is be AUX VBZ relcl True
# in in ADP IN prep True
# God God PROPN NNP pobj False
# , , PUNCT , punct False
# depends depend VERB VBZ ROOT False
# upon upon SCONJ IN prep True
# the the DET DT det True
# knowledge knowledge NOUN NN pobj False
# of of ADP IN prep True
# this this DET DT det True
# truth truth NOUN NN pobj False
# . . PUNCT . punct False
# Therefore therefore ADV RB advmod True
# , , PUNCT , punct False
# in in ADP IN prep True
# order order NOUN NN pobj False
# that that SCONJ IN mark True
# the the DET DT det True
# salvation salvation NOUN NN nsubjpass False
# of of ADP IN prep True
# men man NOUN NNS pobj False
# might may VERB MD aux True
# be be AUX VB auxpass True
# brought bring VERB VBN acl False
# about about ADP RP advmod True
# more more ADV RBR advmod True
# fitly fitly ADV RB advmod False
# and and CCONJ CC cc True
# more more ADV RBR conj True
# surely surely ADV RB advmod False
# , , PUNCT , punct False
# it -PRON- PRON PRP nsubj True
# was be AUX VBD ROOT True
# necessary necessary ADJ JJ acomp False
# that that SCONJ IN mark True
# they -PRON- PRON PRP nsubjpass True
# should should VERB MD aux True
# be be AUX VB auxpass True
# taught teach VERB VBN ccomp False
# divine divine ADJ JJ amod False
# truths truth NOUN NNS dobj False
# by by ADP IN prep True
# divine divine ADJ JJ amod False
# revelation revelation NOUN NN pobj False
# . . PUNCT . punct False
# It -PRON- PRON PRP nsubj True
# was be AUX VBD ROOT True
# therefore therefore ADV RB advmod True
# necessary necessary ADJ JJ acomp False
# that that SCONJ IN mark True
# besides besides SCONJ IN prep True
# philosophical philosophical ADJ JJ amod False
# science science NOUN NN pobj False
# built build VERB VBN acl False
# up up ADP RP prt True
# by by ADP IN agent True
# reason reason NOUN NN pobj False
# , , PUNCT , punct False
# there there PRON EX expl True
# should should VERB MD aux True
# be be AUX VB ccomp True
# a a DET DT det True
# sacred sacred ADJ JJ amod False
# science science NOUN NN attr False
# learned learn VERB VBN acl False
# through through ADP IN prep True
# revelation revelation NOUN NN pobj False
# . . PUNCT . punct False
#
#
#  SPACE _SP  False

# %%
from tqdm import tqdm

class Collector:
    def __self__(self):
        pass
    
    @classmethod
    def collect_logical_units(self, corpus, nlp): 
        self.logical_unit_corpus = []
        for i in tqdm(range(len(corpus)), position=0, leave=True, desc="Collecting Logical Units", ncols=100, bar_format='{l_bar}{bar}|'):
            c = corpus[i]["data"]
            doc = nlp(c)
            # Collect logical units
            logical_units = []
            for token in doc:
                # Catch subjects, objects, nouns, and proper nouns
                if "subj" in token.dep_ or "obj" in token.dep_ or "VERB" == token.pos_:
                    #"NOUN" == token.pos_ or
                    #"PROPN" == token.pos_ or
                    #"ROOT" == token.dep_ or
                    if not token.is_stop:
                        logical_units.append([token.text, (token.dep_, token.pos_)])
            self.logical_unit_corpus.append(logical_units)
        return self.logical_unit_corpus
    
    @classmethod
    def collect_logical_entities(self, corpus, nlp):
        self.logical_entity_corpus = []
        for i in tqdm(range(len(corpus)), position=0, leave=True, desc="Collecting Logical Entities", ncols=100, bar_format='{l_bar}{bar}|'):
            c = corpus[i]["data"]
            
            doc = nlp(c)

            # Collect logical entities
            logical_entities = []
            for ent in doc.ents:
                logical_entities.append([ent, ent.label_])
            self.logical_entity_corpus.append(logical_entities)
        return self.logical_entity_corpus
    
lunits = Collector().collect_logical_units(corpus, nlp)
len(lunits)
#lents = Collector().collect_logical_entities(corpus, nlp)
# Out:
# Collecting Logical Units: 100%|████████████████████████████████████████████████████████████████████|
# 3148

# %%
"""
Rules. 
1. subj - Subject
2. pobj - Object of the Subject
3. 'VERB' - Predicate of the Subject to the Object
"""
import copy

class Subject:
    def __init__(self, name, objects = [], predicates = []):
        #print("[Creating Subject {}]".format(name))
        self.name = name
        self.objects = objects
        self.predicates = predicates
        
    def __str__(self):
        return self.name

    def addObject(self, newObject):
        #print("[Adding Object {}]".format(newObject))
        self.objects.append(newObject)
        
    def addPredicate(self, newPredicate):
        #print("[Adding Predicate {}]".format(newPredicate))
        self.predicates.append(newPredicate)
        
    def objectCount(self):
        return len(self.objects)
    
    def predicateCount(self):
        return len(self.predicates)

# %%
from collections import defaultdict

class Ontology:
    def __self__(self):
        pass
    
    @classmethod
    def createSubjectUnits(self, lunits):
        
        allSubjects = []
        for i in tqdm(range(len(lunits)), position=0, leave=True, desc="Creating Subjects", ncols=100, bar_format='{l_bar}{bar}|'):
            unit = lunits[i]
            subjects = []
            currentSubject = None
            for row in unit:
                word, x = row
                dep, pos = x

                # If Subject
                if "nsubj" == dep:
                    #print("___")

                    """
                    if currentSubject:
                        
                        if (currentSubject.objectCount() < 1 or currentSubject.predicateCount() < 1):
                            
                            # Duplicate name problem
                            if currentSubject.name == word:
                                newName = currentSubject.name
                            else:
                                newName = currentSubject.name + " " + word
                            
                            subject = Subject(newName, currentSubject.objects, currentSubject.predicates)
                            del subjects[-1]
                        else:
                            subject = Subject(word)
                        
                    else:
                        subject = Subject(word)
                    """
                    subject = Subject(word)
                    currentSubject = copy.deepcopy(subject)
                    subjects.append(currentSubject)

                if currentSubject:
                    # If Predicate
                    if pos == "VERB":
                        currentSubject.addPredicate(word)
                    # If Object
                    elif "obj" in dep:
                        currentSubject.addObject(word)

                    #print(row)
            allSubjects.append(subjects)
        return allSubjects
    
    @classmethod
    def displaySubjectUnit(self, subjectUnit):
        
        for row in subjectUnit:
            print("Subject:")
            print("{}".format(row.name))
            print("\tObjects:")
            for obj in row.objects:
                print("\t\t{}".format(obj))
            print("\tPredicates:")
            for pred in row.predicates:
                print("\t\t{}".format(pred))
                
    @classmethod
    def convertSubjectsToList(self, corpus, allSubjects):
        D = []
        for i in tqdm(range(len(allSubjects)), position=0, leave=True, desc="Converting Subjects To List", ncols=100, bar_format='{l_bar}{bar}|'):
            unit = allSubjects[i]
            for row in unit:
                for obj in row.objects:
                    for pred in row.predicates:
                        D.append([corpus[i]["volume"],corpus[i]["question"], corpus[i]["article"], row.name, pred, obj])
        return D
    
    @classmethod
    def convertSubjectsToGraph(self, corpus, allSubjects):
        D = {"nodes":{}, "edges":{}}
        for i in tqdm(range(len(allSubjects)), position=0, leave=True, desc="Converting Subjects To List", ncols=100, bar_format='{l_bar}{bar}|'):
            unit = allSubjects[i]
            for row in unit:
                for obj in row.objects:
                    for pred in row.predicates:
                        
                        if not row.name in list(D["nodes"].keys()):
                            D["nodes"][row.name] = {"type":"subject", "weight":1}
                        else:
                            D["nodes"][row.name]["weight"] += 1
                        
                        if not obj in list(D["nodes"].keys()):
                            D["nodes"][obj] = {"type":"object", "weight":1}
                        else:
                            D["nodes"][obj]["weight"] += 1

                        if not row.name + "_" + obj in list(D["edges"].keys()):  
                            D["edges"][row.name + "_" + obj] = {"weight":1, "from": row.name, "to":obj}
                        else:
                            D["edges"][row.name + "_" + obj]["weight"] += 1
        return D
                
    
subjectUnits = Ontology().createSubjectUnits(lunits)
len(subjectUnits)
# Out:
# Creating Subjects: 100%|███████████████████████████████████████████████████████████████████████████|
# 3148

# %%
Ontology().displaySubjectUnit(subjectUnits[0])
# Out:
# Subject:
# Scripture
# 	Objects:
# 		God
# 		justice
# 	Predicates:
# 		instruct
# 		inspired
# 		teach
# 		correct
# 		reprove
# Subject:
# Scripture
# 	Objects:
# 		God
# 		end
# 		grasp
# 		reason
# 		salvation
# 		science
# 	Predicates:
# 		built
# 		revealed
# 		inspired
# 		surpasses
# 		answer
# 		directed
# Subject:
# hath
# 	Objects:
# 		Thee
# 		things
# 	Predicates:
# 		seen
# Subject:
# Thou hast
# 	Objects:
# 		truths
# 		God
# 		thoughts
# 		men
# 		Thee
# 		end
# 		man
# 		reason
# 		salvation
# 		revelation
# 	Predicates:
# 		wait
# 		exceed
# 		regards
# 		prepared
# 		direct
# 		known
# Subject:
# reason
# 	Objects:
# 		revelation
# 	Predicates:
# 		discovered
# 		taught
# Subject:
# truth
# 	Objects:
# 		God
# 		admixture
# 		reason
# 		errors
# 		time
# 	Predicates:
# 		discover
# 		known
# Subject:
# salvation
# 	Objects:
# 		truths
# 		God
# 		men
# 		truth
# 		reason
# 		order
# 		revelation
# 		knowledge
# 		science
# 	Predicates:
# 		depends
# 		learned
# 		built
# 		brought
# 		taught

# %%
df_ls = Ontology().convertSubjectsToList(corpus, subjectUnits)
df_ls
# Out:
# Converting Subjects To List: 100%|█████████████████████████████████████████████████████████████████|
# [['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'instruct', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'teach', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'correct', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'reprove', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'instruct', 'justice'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'justice'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'teach', 'justice'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'correct', 'justice'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'reprove', 'justice'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'revealed', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'surpasses', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'directed', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'revealed', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'surpasses', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'directed', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'revealed', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'surpasses', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'directed', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'revealed', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'surpasses', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'directed', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Scripture',
#   'revealed',
#   'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Scripture',
#   'inspired',
#   'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Scripture',
#   'surpasses',
#   'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Scripture',
#   'directed',
#   'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'built', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'revealed', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'inspired', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Scripture',
#   'surpasses',
#   'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'answer', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Scripture', 'directed', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'hath', 'seen', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'hath', 'seen', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'thoughts'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'thoughts'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'thoughts'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'prepared',
#   'thoughts'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'thoughts'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'thoughts'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'Thee'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'regards', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'prepared', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'exceed', 'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'regards',
#   'salvation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'prepared',
#   'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'direct', 'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'salvation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'wait', 'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'exceed',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'regards',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'prepared',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'Thou hast',
#   'direct',
#   'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'Thou hast', 'known', 'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'reason',
#   'discovered',
#   'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'reason', 'taught', 'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'discover', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'known', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'discover', 'admixture'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'known', 'admixture'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'discover', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'known', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'discover', 'errors'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'known', 'errors'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'discover', 'time'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'truth', 'known', 'time'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'truths'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'men'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'truth'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'truth'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'truth'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'truth'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'truth'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'order'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'depends',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'learned',
#   'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'brought',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'taught',
#   'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'depends',
#   'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'learned',
#   'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 1.',
#   'salvation',
#   'brought',
#   'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'depends', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'learned', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'built', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'brought', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 1.', 'salvation', 'taught', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'protected',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'strengthened',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'says',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'belongs',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'nourished',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'said',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'saving',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'protected',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'strengthened',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'says',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'belongs',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'nourished',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'said',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'saving',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'protected',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'strengthened',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'says',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'belongs',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'nourished',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'said',
#   'faith'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'Augustine Trin xiv',
#   'saving',
#   'faith'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'principle'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'principle'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'mind'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'mind'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'mind'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'established', 'mind'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'mind'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'sciences'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'arithmetic'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'proceed',
#   'arithmetic'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'arithmetic'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'arithmetic'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'arithmetic'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'intelligence'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'proceed',
#   'intelligence'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'answer',
#   'intelligence'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'intelligence'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'known',
#   'intelligence'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'geometry'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'geometry'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'geometry'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'geometry'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'geometry'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'established', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'proceed',
#   'principles'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'principles'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'principles'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'proceeds'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'proceeds'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'proceeds'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'proceeds'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'proceeds'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'bear', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceed', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'answer', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'science'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'known', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'established', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceeds', 'light'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'science'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceeds', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'established',
#   'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'doctrine',
#   'proceeds',
#   'principles'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'established', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'doctrine', 'proceeds', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'musician', 'accepts', 'authority'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'principles', 'established', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'principles', 'taught', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 2.', 'principles', 'revealed', 'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'established',
#   'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'taught',
#   'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'revealed',
#   'principles'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'established',
#   'mathematician'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'taught',
#   'mathematician'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 2.',
#   'principles',
#   'revealed',
#   'mathematician'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'Scripture', 'speaks', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'Wisdom', 'gave', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'Wisdom', 'answer', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'Wisdom', 'gave', 'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'Wisdom', 'answer', 'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'regards',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'gauged',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'regards',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'gauged',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'regards',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'gauged',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'regards',
#   'faculty'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'gauged',
#   'faculty'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'regards',
#   'example'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'doctrine unity',
#   'gauged',
#   'example'],
#  ['Volume 1', 'Question 1.', 'Article 3.', 'man stone', 'agree', 'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'man stone',
#   'colored',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'formality'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'doctrine'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'sight'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'sight'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'sight'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'sight'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'included',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'possesses',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'revealed',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 3.',
#   'color Scripture',
#   'considers',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine handiwork',
#   'answer',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine',
#   'considers',
#   'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'known', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'extends', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'belong', 'sciences'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine',
#   'considers',
#   'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'known', 'revelation'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine',
#   'extends',
#   'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'belong', 'revelation'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'considers', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'known', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'extends', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'belong', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'considers', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'known', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'extends', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine', 'belong', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'knows', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'treat', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'ordained', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'consists', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'includes', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'knows', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'treat', 'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'ordained',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'consists',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'includes',
#   'things'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'knows', 'bliss'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'treat', 'bliss'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'ordained',
#   'bliss'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'consists',
#   'bliss'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'includes',
#   'bliss'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'knows',
#   'Objections'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'treat',
#   'Objections'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'ordained',
#   'Objections'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'consists',
#   'Objections'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'includes',
#   'Objections'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'knows',
#   'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'treat',
#   'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'ordained',
#   'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'consists',
#   'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 4.',
#   'doctrine God',
#   'includes',
#   'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'knows', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'treat', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'ordained', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'consists', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 4.', 'doctrine God', 'includes', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'invite', 'maids'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'sent', 'maids'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'answer', 'maids'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'invite', 'tower'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'sent', 'tower'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'Wisdom', 'answer', 'tower'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'said', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcends', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'said', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcends', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'said', 'certitude'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 5.',
#   'science',
#   'transcends',
#   'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'said', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcends', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'said', 'respects'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 5.',
#   'science',
#   'transcends',
#   'respects'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'surpasses', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'surpasses', 'point'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 5.',
#   'science',
#   'surpasses',
#   'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'matter'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'certitude'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'worth'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'point'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'point'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'point'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'point'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derives', 'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'misled', 'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'derive', 'knowledge'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'err', 'knowledge'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 5.',
#   'science',
#   'transcend',
#   'sublimity'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'treats', 'sublimity'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcend', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'treats', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcend', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'treats', 'reason'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'transcend', 'chiefly'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'treats', 'chiefly'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'ordained', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'consider', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'ordained', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'consider', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'ordained', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'consider', 'grasp'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'ordained', 'purpose'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'sciences', 'consider', 'purpose'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'directed', 'army'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'directed', 'State'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'directed', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'science', 'directed', 'good'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'purpose', 'directed', 'sciences'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'purpose', 'directed', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 5.', 'purpose', 'directed', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 5.',
#   'purpose',
#   'directed',
#   'standpoint'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'building'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 6.',
#   'doctrine',
#   'considers',
#   'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'building'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'principle'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 6.',
#   'doctrine',
#   'considers',
#   'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'principle'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'laborers'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 6.',
#   'doctrine',
#   'considers',
#   'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'laborers'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'form'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'wood'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'wisdom'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'light'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'opposition'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 6.',
#   'doctrine',
#   'arrange',
#   'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'opposition'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 6.',
#   'doctrine',
#   'considers',
#   'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'opposition'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'called', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'trim', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'said', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'arrange', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'plans', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judged', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'considers', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'doctrine', 'judge', 'house'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'life'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'life'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'life'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'architect'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'architect'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'architect'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'end'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'foundation'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'foundation'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'foundation'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'directs', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'laid', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'stones', 'called', 'acts'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'said', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'called', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'considers', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'said', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'called', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'considers', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'said', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'called', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'considers', 'man'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'said', 'universe'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'called', 'universe'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Wisdom', 'considers', 'universe'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'viewed', 'creatures'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'known', 'creatures'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'says', 'creatures'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'viewed', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'known', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'says', 'cause'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'viewed', 'Trin'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'known', 'Trin'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'says', 'Trin'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'viewed', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'known', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'Augustine', 'says', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'philosophers', 'known', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'philosophers', 'knew', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'philosophers', 'revealed', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 6.', 'philosophers', 'called', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'treats', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'treatment', 'called', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'treatment', 'called', 'treating'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'God', 'answer', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God relation',
#   'speaking',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God relation',
#   'speaking',
#   'habit'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'referred', 'sight'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'colored', 'sight'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'referred', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'colored', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'referred', 'faculty'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'object', 'colored', 'faculty'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'follows', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'refer', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'treated', 'aspect'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'follows', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'refer', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'treated', 'God'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'follows', 'beginning'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'refer', 'beginning'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'treated', 'beginning'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'follows', 'sight'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'refer', 'sight'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'treated', 'sight'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'follows', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'refer', 'science'],
#  ['Volume 1', 'Question 1.', 'Article 7.', 'things', 'treated', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treat',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treated',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'asserted',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'looking',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'contained',
#   'object'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treat',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treated',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'asserted',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'looking',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'contained',
#   'God'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treat',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treated',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'asserted',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'looking',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'contained',
#   'aspect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treat',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'treated',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'asserted',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
#   'God articles object',
#   'looking',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 7.',
# ...
#  ['Volume 1', 'Question 1.', 'Article 9.', 'God', 'taught', 'nature'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'God', 'attain', 'nature'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'enlightened', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'wise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'covering'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'covering'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'proposed',
#   'covering'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'befitting',
#   'covering'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'covering'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'covering'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'expounded',
#   'covering'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'means'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'means'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'veils'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'veils'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'order'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'order'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'figures'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'figures'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'figures'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'befitting',
#   'figures'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'figures'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'figures'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'expounded',
#   'figures'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'enlightened', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'unwise'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'unwise'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'taken',
#   'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'proposed',
#   'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'befitting',
#   'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'hidden',
#   'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'distinction'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'expounded',
#   'distinction'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'persons'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'persons'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'persons'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'befitting',
#   'persons'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'persons'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'enlightened',
#   'persons'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 9.',
#   'Dionysius',
#   'expounded',
#   'persons'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'says', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'taken', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'proposed', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'befitting', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'hidden', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'enlightened', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'Dionysius', 'expounded', 'rays'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'simple', 'understand', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 9.', 'simple', 'grasp', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'says', 'manner'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'describes',
#   'manner'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'reveals', 'manner'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'answer', 'manner'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'transcends',
#   'manner'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'says', 'speech'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'describes',
#   'speech'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'reveals', 'speech'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'answer', 'speech'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'transcends',
#   'speech'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'says', 'fact'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'describes', 'fact'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'reveals', 'fact'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'answer', 'fact'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'transcends',
#   'fact'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'says', 'mystery'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'describes',
#   'mystery'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'reveals',
#   'mystery'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'answer', 'mystery'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'transcends',
#   'mystery'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'says', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'describes',
#   'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'reveals',
#   'science'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Gregory xx', 'answer', 'science'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'Gregory xx',
#   'transcends',
#   'science'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'author', 'signify', 'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'author', 'signify', 'meaning'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'author', 'signify', 'words'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'man', 'signified', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'man', 'signified', 'words'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'science things',
#   'signified',
#   'signification'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'science things',
#   'signified',
#   'property'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'science things',
#   'signified',
#   'words'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'signification words',
#   'belongs',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'signification words',
#   'signify',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'signification words',
#   'belongs',
#   'sense'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'signification words',
#   'signify',
#   'sense'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'based', 'literal'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signified', 'literal'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'things',
#   'presupposes',
#   'literal'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'called', 'literal'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'based', 'words'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signified', 'words'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'presupposes', 'words'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'called', 'words'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense Apostle',
#   'says',
#   'Hebrews'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense Apostle',
#   'says',
#   'division'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Law Dionysius', 'says', 'Law'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Law Head', 'ought', 'Law'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Law Head', 'ought', 'glory'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signify', 'Law'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signify', 'things'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'relates', 'glory'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signify', 'glory'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'ought', 'glory'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'relates', 'Christ'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'signify', 'Christ'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'things', 'ought', 'Christ'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'comprehends',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'unfitting',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'intends',
#   'things'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'comprehends',
#   'intellect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'unfitting',
#   'intellect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'intends',
#   'intellect'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'comprehends',
#   'act'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'unfitting',
#   'act'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'sense author', 'intends', 'act'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'comprehends',
#   'Writ'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'unfitting',
#   'Writ'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'sense author', 'intends', 'Writ'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'comprehends',
#   'author'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'unfitting',
#   'author'],
#  ['Volume 1',
#   'Question 1.',
#   'Article 10.',
#   'sense author',
#   'intends',
#   'author'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Augustine', 'according', 'sense'],
#  ['Volume 1', 'Question 1.', 'Article 10.', 'Augustine', 'says', 'sense'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God fool', 'said', 'heart'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God fool', 'admitted', 'heart'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'exists', 'ways'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'answer', 'ways'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'exists', 'evident'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'answer', 'evident'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'exists', 'hand'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'God thing', 'answer', 'hand'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition',
#   'included',
#   'essence'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition',
#   'included',
#   'subject'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'known', 'animal'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'contained', 'animal'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'known', 'predicate'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'contained', 'predicate'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'known', 'man'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'contained', 'man'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'known', 'essence'],
#  ['Volume 1', 'Question 2.', 'Article 1.', 'Man', 'contained', 'essence'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'know',
#   'regard'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'happens',
#   'regard'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'know',
#   'proposition'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'happens',
#   'proposition'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'know',
#   'principles'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'happens',
#   'principles'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'know',
#   'demonstration'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'happens',
#   'demonstration'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'know',
#   'meaning'],
#  ['Volume 1',
#   'Question 2.',
#   'Article 1.',
#   'proposition terms essence proposition',
#   'happens',
#   'meaning'],
#  ...]

# %%
df_graph = Ontology().convertSubjectsToGraph(corpus, subjectUnits)
df_graph
# Out:
# Converting Subjects To List: 100%|█████████████████████████████████████████████████████████████████|
# {'nodes': {'Scripture': {'type': 'subject', 'weight': 641},
#   'God': {'type': 'object', 'weight': 24653},
#   'justice': {'type': 'object', 'weight': 2928},
#   'end': {'type': 'object', 'weight': 4818},
#   'grasp': {'type': 'object', 'weight': 17},
#   'reason': {'type': 'object', 'weight': 12194},
#   'salvation': {'type': 'object', 'weight': 1004},
#   'science': {'type': 'object', 'weight': 553},
#   'hath': {'type': 'subject', 'weight': 1906},
#   'Thee': {'type': 'object', 'weight': 238},
#   'things': {'type': 'object', 'weight': 18133},
#   'Thou hast': {'type': 'subject', 'weight': 69},
#   'truths': {'type': 'object', 'weight': 91},
#   'thoughts': {'type': 'object', 'weight': 271},
#   'men': {'type': 'object', 'weight': 5486},
#   'man': {'type': 'object', 'weight': 37296},
#   'revelation': {'type': 'object', 'weight': 407},
#   'truth': {'type': 'subject', 'weight': 3153},
#   'admixture': {'type': 'object', 'weight': 143},
#   'errors': {'type': 'object', 'weight': 90},
#   'time': {'type': 'object', 'weight': 2864},
#   'order': {'type': 'object', 'weight': 7806},
#   'knowledge': {'type': 'object', 'weight': 5773},
#   'Augustine Trin xiv': {'type': 'subject', 'weight': 21},
#   'doctrine': {'type': 'object', 'weight': 632},
#   'faith': {'type': 'object', 'weight': 4111},
#   'principle': {'type': 'object', 'weight': 2406},
#   'mind': {'type': 'object', 'weight': 2756},
#   'sciences': {'type': 'object', 'weight': 207},
#   'arithmetic': {'type': 'object', 'weight': 5},
#   'intelligence': {'type': 'object', 'weight': 253},
#   'geometry': {'type': 'object', 'weight': 17},
#   'light': {'type': 'object', 'weight': 1246},
#   'principles': {'type': 'object', 'weight': 1786},
#   'proceeds': {'type': 'object', 'weight': 84},
#   'musician': {'type': 'subject', 'weight': 1},
#   'authority': {'type': 'object', 'weight': 1907},
#   'mathematician': {'type': 'object', 'weight': 3},
#   'Wisdom': {'type': 'subject', 'weight': 216},
#   'doctrine unity': {'type': 'subject', 'weight': 10},
#   'object': {'type': 'object', 'weight': 3782},
#   'aspect': {'type': 'object', 'weight': 664},
#   'formality': {'type': 'object', 'weight': 22},
#   'faculty': {'type': 'object', 'weight': 637},
#   'example': {'type': 'object', 'weight': 579},
#   'man stone': {'type': 'subject', 'weight': 2},
#   'color Scripture': {'type': 'subject', 'weight': 24},
#   'sight': {'type': 'object', 'weight': 908},
#   'doctrine handiwork': {'type': 'subject', 'weight': 1},
#   'doctrine God': {'type': 'subject', 'weight': 30},
#   'bliss': {'type': 'object', 'weight': 104},
#   'Objections': {'type': 'object', 'weight': 382},
#   'acts': {'type': 'object', 'weight': 2474},
#   'maids': {'type': 'object', 'weight': 6},
#   'tower': {'type': 'object', 'weight': 6},
#   'matter': {'type': 'object', 'weight': 4105},
#   'certitude': {'type': 'object', 'weight': 109},
#   'worth': {'type': 'object', 'weight': 46},
#   'respects': {'type': 'object', 'weight': 182},
#   'point': {'type': 'object', 'weight': 1280},
#   'sublimity': {'type': 'object', 'weight': 5},
#   'chiefly': {'type': 'object', 'weight': 168},
#   'purpose': {'type': 'object', 'weight': 1299},
#   'army': {'type': 'object', 'weight': 52},
#   'State': {'type': 'object', 'weight': 32},
#   'good': {'type': 'object', 'weight': 6103},
#   'standpoint': {'type': 'object', 'weight': 45},
#   'building': {'type': 'object', 'weight': 47},
#   'laborers': {'type': 'object', 'weight': 8},
#   'form': {'type': 'object', 'weight': 4838},
#   'wood': {'type': 'object', 'weight': 191},
#   'wisdom': {'type': 'object', 'weight': 1149},
#   'opposition': {'type': 'object', 'weight': 456},
#   'house': {'type': 'object', 'weight': 511},
#   'stones': {'type': 'subject', 'weight': 89},
#   'life': {'type': 'object', 'weight': 5120},
#   'architect': {'type': 'object', 'weight': 57},
#   'foundation': {'type': 'object', 'weight': 94},
#   'cause': {'type': 'object', 'weight': 3953},
#   'universe': {'type': 'object', 'weight': 210},
#   'Augustine': {'type': 'subject', 'weight': 10795},
#   'creatures': {'type': 'object', 'weight': 1275},
#   'Trin': {'type': 'object', 'weight': 299},
#   'philosophers': {'type': 'subject', 'weight': 630},
#   'treatment': {'type': 'subject', 'weight': 19},
#   'treating': {'type': 'object', 'weight': 36},
#   'God relation': {'type': 'subject', 'weight': 2},
#   'habit': {'type': 'object', 'weight': 1561},
#   'beginning': {'type': 'object', 'weight': 635},
#   'God articles object': {'type': 'subject', 'weight': 55},
#   'head': {'type': 'object', 'weight': 540},
#   'reference': {'type': 'object', 'weight': 797},
#   'Scripture bishop': {'type': 'subject', 'weight': 18},
#   'word': {'type': 'object', 'weight': 2313},
#   'gainsayers': {'type': 'object', 'weight': 17},
#   'proof': {'type': 'object', 'weight': 381},
#   'Apostle': {'type': 'subject', 'weight': 5526},
#   'regard': {'type': 'object', 'weight': 2219},
#   'resurrection': {'type': 'object', 'weight': 786},
#   'Christ': {'type': 'object', 'weight': 12201},
#   'highest': {'type': 'object', 'weight': 26},
#   'metaphysics': {'type': 'subject', 'weight': 2},
#   'opponent': {'type': 'subject', 'weight': 50},
#   'objections': {'type': 'object', 'weight': 283},
#   'dispute': {'type': 'object', 'weight': 7},
#   'concession': {'type': 'object', 'weight': 2},
#   'heretics': {'type': 'object', 'weight': 299},
#   'texts': {'type': 'object', 'weight': 4},
#   'article': {'type': 'object', 'weight': 179},
#   'Writ': {'type': 'object', 'weight': 244},
#   'articles': {'type': 'object', 'weight': 195},
#   'arguments': {'type': 'subject', 'weight': 176},
#   'comparisons': {'type': 'object', 'weight': 19},
#   'means': {'type': 'object', 'weight': 1758},
#   'metaphors': {'type': 'object', 'weight': 3},
#   'likeness': {'type': 'object', 'weight': 1073},
#   'objects': {'type': 'object', 'weight': 876},
#   'sense': {'type': 'object', 'weight': 2956},
#   'capacity': {'type': 'object', 'weight': 140},
#   'nature': {'type': 'object', 'weight': 9549},
#   'Dionysius': {'type': 'subject', 'weight': 1904},
#   'wise': {'type': 'object', 'weight': 62},
#   'covering': {'type': 'object', 'weight': 10},
#   'veils': {'type': 'object', 'weight': 14},
#   'figures': {'type': 'object', 'weight': 87},
#   'unwise': {'type': 'object', 'weight': 34},
#   'distinction': {'type': 'object', 'weight': 2181},
#   'persons': {'type': 'object', 'weight': 1606},
#   'rays': {'type': 'object', 'weight': 30},
#   'simple': {'type': 'subject', 'weight': 21},
#   'Gregory xx': {'type': 'subject', 'weight': 25},
#   'manner': {'type': 'object', 'weight': 2818},
#   'speech': {'type': 'object', 'weight': 221},
#   'fact': {'type': 'object', 'weight': 1682},
#   'mystery': {'type': 'object', 'weight': 331},
#   'author': {'type': 'subject', 'weight': 113},
#   'meaning': {'type': 'object', 'weight': 243},
#   'words': {'type': 'object', 'weight': 3576},
#   'science things': {'type': 'subject', 'weight': 3},
#   'signification': {'type': 'object', 'weight': 1132},
#   'property': {'type': 'object', 'weight': 542},
#   'signification words': {'type': 'subject', 'weight': 4},
#   'literal': {'type': 'object', 'weight': 4},
#   'sense Apostle': {'type': 'subject', 'weight': 2},
#   'Hebrews': {'type': 'object', 'weight': 305},
#   'division': {'type': 'object', 'weight': 347},
#   'Law Dionysius': {'type': 'subject', 'weight': 1},
#   'Law': {'type': 'object', 'weight': 3538},
#   'Law Head': {'type': 'subject', 'weight': 2},
#   'glory': {'type': 'object', 'weight': 1921},
#   'sense author': {'type': 'subject', 'weight': 15},
#   'intellect': {'type': 'object', 'weight': 6261},
#   'act': {'type': 'object', 'weight': 5492},
#   'God fool': {'type': 'subject', 'weight': 2},
#   'heart': {'type': 'object', 'weight': 1129},
#   'God thing': {'type': 'subject', 'weight': 73},
#   'ways': {'type': 'object', 'weight': 4429},
#   'evident': {'type': 'object', 'weight': 47},
#   'hand': {'type': 'object', 'weight': 2410},
#   'proposition': {'type': 'subject', 'weight': 153},
#   'essence': {'type': 'object', 'weight': 1925},
#   'subject': {'type': 'object', 'weight': 1345},
#   'Man': {'type': 'subject', 'weight': 900},
#   'animal': {'type': 'object', 'weight': 565},
#   'predicate': {'type': 'object', 'weight': 58},
#   'proposition terms essence proposition': {'type': 'subject', 'weight': 12},
#   'demonstration': {'type': 'object', 'weight': 116},
#   'Boethius title substances': {'type': 'subject', 'weight': 2},
#   'space': {'type': 'object', 'weight': 174},
#   'proposition God': {'type': 'subject', 'weight': 3},
#   'I:3:4': {'type': 'object', 'weight': 30},
#   'effects': {'type': 'object', 'weight': 970},
#   'thing': {'type': 'object', 'weight': 8598},
#   'effect': {'type': 'object', 'weight': 2342},
#   'effect cause': {'type': 'subject', 'weight': 52},
#   'way things thing': {'type': 'subject', 'weight': 30},
#   'fire': {'type': 'object', 'weight': 2230},
#   'senses': {'type': 'object', 'weight': 1082},
#   'motion': {'type': 'object', 'weight': 411},
#   'reduction': {'type': 'object', 'weight': 8},
#   'potentiality': {'type': 'object', 'weight': 862},
#   'state': {'type': 'object', 'weight': 2898},
#   'actuality': {'type': 'object', 'weight': 81},
#   'world': {'type': 'object', 'weight': 1698},
#   'respect': {'type': 'object', 'weight': 3233},
#   'way': {'type': 'object', 'weight': 7152},
#   'infinity': {'type': 'object', 'weight': 158},
#   'movers staff': {'type': 'subject', 'weight': 12},
#   'inasmuch': {'type': 'object', 'weight': 1200},
#   'mover': {'type': 'object', 'weight': 375},
#   'causes': {'type': 'object', 'weight': 1008},
#   'intermediate cause': {'type': 'subject', 'weight': 108},
#   'possibility': {'type': 'object', 'weight': 47},
#   'existence': {'type': 'object', 'weight': 831},
#   'beings existence thing': {'type': 'subject', 'weight': 42},
#   'necessity': {'type': 'object', 'weight': 1251},
#   'gradation': {'type': 'object', 'weight': 9},
#   'Metaph': {'type': 'object', 'weight': 227},
#   'beings': {'type': 'object', 'weight': 696},
#   'maximum cause': {'type': 'subject', 'weight': 8},
#   'governance': {'type': 'object', 'weight': 36},
#   'genus': {'type': 'object', 'weight': 790},
#   'acting': {'type': 'object', 'weight': 40},
#   'bodies': {'type': 'object', 'weight': 2222},
#   'archer': {'type': 'object', 'weight': 49},
#   'mark': {'type': 'object', 'weight': 57},
#   'result': {'type': 'object', 'weight': 759},
#   'body': {'type': 'subject', 'weight': 7499},
#   'induction': {'type': 'object', 'weight': 1},
#   'God body continuous God God body': {'type': 'subject', 'weight': 10},
#   'bodies animation': {'type': 'subject', 'weight': 1},
#   'soul': {'type': 'object', 'weight': 8312},
#   'animation': {'type': 'object', 'weight': 22},
#   'Article': {'type': 'object', 'weight': 2196},
#   'I:2:3': {'type': 'object', 'weight': 24},
#   'perfection': {'type': 'object', 'weight': 4109},
#   'God good': {'type': 'subject', 'weight': 16},
#   'agent': {'type': 'subject', 'weight': 1571},
#   'manner God': {'type': 'subject', 'weight': 3},
#   'relation': {'type': 'subject', 'weight': 1959},
#   'Godhead': {'type': 'object', 'weight': 760},
#   'suppositum': {'type': 'object', 'weight': 171},
#   'definition': {'type': 'object', 'weight': 579},
#   'species': {'type': 'object', 'weight': 3118},
#   'humanity': {'type': 'subject', 'weight': 171},
#   'man humanity man': {'type': 'subject', 'weight': 24},
#   'flesh': {'type': 'object', 'weight': 1663},
#   'accidents': {'type': 'object', 'weight': 273},
#   'thing humanity': {'type': 'subject', 'weight': 42},
#   'constituent': {'type': 'object', 'weight': 6},
#   'individualization': {'type': 'subject', 'weight': 2},
#   'forms': {'type': 'object', 'weight': 1274},
#   'supposita': {'type': 'object', 'weight': 50},
#   'Hilary': {'type': 'subject', 'weight': 246},
#   'laughing': {'type': 'object', 'weight': 10},
#   'water': {'type': 'object', 'weight': 819},
#   'thing existence': {'type': 'subject', 'weight': 6},
#   'goodness': {'type': 'object', 'weight': 1346},
#   'essence God': {'type': 'subject', 'weight': 8},
#   'participation': {'type': 'object', 'weight': 442},
#   'quantity': {'type': 'object', 'weight': 1059},
#   'concretion': {'type': 'object', 'weight': 5},
#   'actuality argument': {'type': 'subject', 'weight': 8},
#   'existence God': {'type': 'subject', 'weight': 10},
#   'essential': {'type': 'object', 'weight': 19},
#   'Philosopher': {'type': 'subject', 'weight': 4127},
#   'differences': {'type': 'object', 'weight': 97},
#   'difference God': {'type': 'subject', 'weight': 70},
#   'horse': {'type': 'object', 'weight': 73},
#   'quiddity': {'type': 'object', 'weight': 147},
#   'member': {'type': 'object', 'weight': 161},
#   'God mean God principle': {'type': 'subject', 'weight': 5},
#   'point God': {'type': 'subject', 'weight': 3},
#   'accident God form Boethius': {'type': 'subject', 'weight': 40},
#   'God Boethius': {'type': 'subject', 'weight': 1},
#   'Hebdom': {'type': 'object', 'weight': 1},
#   'essence substance': {'type': 'subject', 'weight': 4},
#   'whiteness': {'type': 'object', 'weight': 140},
#   'heat God capability': {'type': 'subject', 'weight': 14},
#   'heat': {'type': 'object', 'weight': 517},
#   'Augustine Trin God': {'type': 'subject', 'weight': 18},
#   'parts': {'type': 'object', 'weight': 1252},
#   'question': {'type': 'object', 'weight': 890},
#   'composition': {'type': 'object', 'weight': 151},
#   'God composite God': {'type': 'subject', 'weight': 2},
#   'composite': {'type': 'subject', 'weight': 59},
#   'foot': {'type': 'object', 'weight': 89},
#   'wholes': {'type': 'object', 'weight': 4},
#   'air': {'type': 'object', 'weight': 514},
#   'instance': {'type': 'object', 'weight': 2609},
#   'volume': {'type': 'subject', 'weight': 12},
#   'white': {'type': 'object', 'weight': 46},
#   'God Hilary': {'type': 'subject', 'weight': 12},
#   'argument': {'type': 'object', 'weight': 179},
#   'Dionysius cause': {'type': 'subject', 'weight': 5},
#   'opinion': {'type': 'object', 'weight': 2352},
#   'heaven': {'type': 'object', 'weight': 1432},
#   'God error': {'type': 'subject', 'weight': 4},
#   'David': {'type': 'object', 'weight': 328},
#   'Almaricians': {'type': 'object', 'weight': 1},
#   'Dinant': {'type': 'object', 'weight': 1},
#   'formal': {'type': 'object', 'weight': 7},
#   'God cause form': {'type': 'subject', 'weight': 2},
#   'matter God': {'type': 'subject', 'weight': 6},
#   'composite hand': {'type': 'subject', 'weight': 4},
#   'God potentiality form': {'type': 'subject', 'weight': 5},
#   'foregoing': {'type': 'object', 'weight': 51},
#   'compound': {'type': 'object', 'weight': 5},
#   'participates fire': {'type': 'subject', 'weight': 6},
#   'Lord': {'type': 'subject', 'weight': 5638},
#   'desirableness': {'type': 'object', 'weight': 9},
#   'like': {'type': 'object', 'weight': 670},
#   'agent God aspect': {'type': 'subject', 'weight': 6},
#   'iv': {'type': 'subject', 'weight': 635},
#   'Trinity': {'type': 'subject', 'weight': 375},
#   'minds': {'type': 'object', 'weight': 238},
#   'inasmuch perfections': {'type': 'subject', 'weight': 30},
#   'I:4:2': {'type': 'object', 'weight': 26},
#   'sun': {'type': 'object', 'weight': 640},
#   'Boethius things': {'type': 'subject', 'weight': 24},
#   'constitution': {'type': 'object', 'weight': 25},
#   'operation': {'type': 'object', 'weight': 1499},
#   'attaining': {'type': 'object', 'weight': 9},
#   'place': {'type': 'object', 'weight': 2803},
#   'creature': {'type': 'object', 'weight': 1827},
#   'I:3:6': {'type': 'object', 'weight': 4},
#   'denomination': {'type': 'object', 'weight': 9},
#   'measure': {'type': 'object', 'weight': 771},
#   'opinions Plato': {'type': 'subject', 'weight': 63},
#   'idea': {'type': 'object', 'weight': 587},
#   'ideas': {'type': 'object', 'weight': 150},
#   'subsisting': {'type': 'object', 'weight': 7},
#   'Aristotle': {'type': 'subject', 'weight': 538},
#   'assimilation': {'type': 'object', 'weight': 27},
#   'similitude': {'type': 'object', 'weight': 318},
#   'exemplary': {'type': 'object', 'weight': 7},
#   'I:4:3': {'type': 'object', 'weight': 10},
#   'Augustine Doctr': {'type': 'subject', 'weight': 409},
#   'Goodness': {'type': 'subject', 'weight': 4},
#   'Philosopher Goodness thing': {'type': 'subject', 'weight': 2},
#   'thing things': {'type': 'subject', 'weight': 21},
#   'creature God': {'type': 'subject', 'weight': 5},
#   'sort': {'type': 'object', 'weight': 114},
#   'desirability': {'type': 'object', 'weight': 5},
#   'sake': {'type': 'object', 'weight': 958},
#   'goodness things': {'type': 'subject', 'weight': 2},
#   'action': {'type': 'subject', 'weight': 3389},
#   'form converse': {'type': 'subject', 'weight': 3},
#   'power': {'type': 'subject', 'weight': 8346},
#   'Augustine Nat': {'type': 'subject', 'weight': 2},
#   'mode': {'type': 'object', 'weight': 1449},
#   'God things things essence': {'type': 'subject', 'weight': 3},
#   '1': {'type': 'object', 'weight': 127},
#   'precedes': {'type': 'object', 'weight': 199},
#   'determination': {'type': 'object', 'weight': 115},
#   'definitions': {'type': 'object', 'weight': 30},
#   'numbers': {'type': 'object', 'weight': 108},
#   'unit': {'type': 'subject', 'weight': 6},
#   'number': {'type': 'object', 'weight': 933},
#   'difference': {'type': 'subject', 'weight': 1841},
#   'inclination': {'type': 'object', 'weight': 869},
#   'weight': {'type': 'object', 'weight': 133},
#   'accordance': {'type': 'object', 'weight': 471},
#   'honestum': {'type': 'subject', 'weight': 6},
#   'fitting': {'type': 'object', 'weight': 5},
#   'contrary': {'type': 'object', 'weight': 932},
#   'Ambrose': {'type': 'subject', 'weight': 1394},
#   'use': {'type': 'object', 'weight': 2639},
#   'view': {'type': 'object', 'weight': 581},
#   'movement': {'type': 'object', 'weight': 3362},
#   'consideration': {'type': 'object', 'weight': 780},
#   'appetite': {'type': 'object', 'weight': 1865},
#   'rest': {'type': 'object', 'weight': 316},
#   'virtuous': {'type': 'object', 'weight': 21},
#   'terminates': {'type': 'subject', 'weight': 51},
#   'Father Philosopher philosophers': {'type': 'subject', 'weight': 3},
#   'reason philosophers principle': {'type': 'subject', 'weight': 1},
#   'principle God principle': {'type': 'subject', 'weight': 18},
#   'proportion': {'type': 'object', 'weight': 420},
#   'Dionysius God': {'type': 'subject', 'weight': 326},
#   'perfections': {'type': 'subject', 'weight': 218},
#   'Commentator': {'type': 'subject', 'weight': 19},
#   'considerations': {'type': 'object', 'weight': 46},
#   'man reproduces': {'type': 'subject', 'weight': 6},
#   'degree': {'type': 'object', 'weight': 1307},
#   'matter agent': {'type': 'subject', 'weight': 9},
#   'imperfect': {'type': 'object', 'weight': 100},
#   'God perfections': {'type': 'subject', 'weight': 9},
#   'line': {'type': 'object', 'weight': 96},
#   'virtue': {'type': 'object', 'weight': 4640},
#   'fashion': {'type': 'object', 'weight': 242},
#   'limitation': {'type': 'object', 'weight': 4},
#   'analogy': {'type': 'object', 'weight': 12},
#   'Damascene God philosophers': {'type': 'subject', 'weight': 15},
#   'infinitude': {'type': 'object', 'weight': 13},
#   'consequence': {'type': 'object', 'weight': 438},
#   'infinite': {'type': 'subject', 'weight': 135},
#   'Reply': {'type': 'object', 'weight': 701},
#   'Objection': {'type': 'object', 'weight': 1051},
#   'Phys': {'type': 'object', 'weight': 153},
#   'Things': {'type': 'subject', 'weight': 148},
#   'shapes': {'type': 'object', 'weight': 38},
#   'things forms': {'type': 'subject', 'weight': 8},
#   'case': {'type': 'subject', 'weight': 1955},
#   'angels': {'type': 'object', 'weight': 3392},
#   'body surface bodies': {'type': 'subject', 'weight': 20},
#   'surface': {'type': 'object', 'weight': 94},
#   'magnitude': {'type': 'object', 'weight': 108},
#   'premises': {'type': 'object', 'weight': 32},
#   'individuality': {'type': 'object', 'weight': 16},
#   'place forasmuch': {'type': 'subject', 'weight': 32},
#   'centre': {'type': 'object', 'weight': 49},
#   'body lines': {'type': 'subject', 'weight': 8},
#   'form body': {'type': 'subject', 'weight': 3},
#   'term': {'type': 'object', 'weight': 694},
#   'figure': {'type': 'object', 'weight': 314},
#   'hast': {'type': 'subject', 'weight': 904},
#   'Avicenna': {'type': 'object', 'weight': 119},
#   'multitude': {'type': 'subject', 'weight': 356},
#   'generation': {'type': 'subject', 'weight': 1128},
#   'medium': {'type': 'object', 'weight': 258},
#   'work': {'type': 'object', 'weight': 1286},
#   'carpenter': {'type': 'object', 'weight': 10},
#   'little': {'type': 'object', 'weight': 132},
#   'accident': {'type': 'object', 'weight': 214},
#   'hammers': {'type': 'object', 'weight': 5},
#   'kind': {'type': 'subject', 'weight': 2455},
#   'Creator': {'type': 'object', 'weight': 170},
#   'intention': {'type': 'object', 'weight': 1559},
#   'multitude increase': {'type': 'subject', 'weight': 6},
#   'continuous': {'type': 'object', 'weight': 19},
#   'rule': {'type': 'object', 'weight': 633},
#   'addition': {'type': 'object', 'weight': 404},
#   'thing God': {'type': 'subject', 'weight': 41},
#   'Isaiah': {'type': 'object', 'weight': 251},
#   'Vulgate': {'type': 'object', 'weight': 226},
#   'works': {'type': 'object', 'weight': 1627},
#   'God agent': {'type': 'subject', 'weight': 36},
#   'air thing God': {'type': 'subject', 'weight': 25},
#   'I:7:1': {'type': 'object', 'weight': 12},
#   'presence': {'type': 'object', 'weight': 374},
#   'gloss': {'type': 'subject', 'weight': 2294},
#   'Canticles': {'type': 'object', 'weight': 9},
#   'Canticle': {'type': 'object', 'weight': 4},
#   'grace': {'type': 'object', 'weight': 4149},
#   'quotation': {'type': 'subject', 'weight': 230},
#   'Gregory': {'type': 'object', 'weight': 3108},
#   'Ezech': {'type': 'object', 'weight': 80},
#   'operator': {'type': 'object', 'weight': 33},
#   'operations': {'type': 'object', 'weight': 793},
#   'affairs': {'type': 'object', 'weight': 251},
#   'kingdom': {'type': 'object', 'weight': 404},
#   'prerogative': {'type': 'object', 'weight': 17},
#   'substance': {'type': 'object', 'weight': 1521},
#   'inspection': {'type': 'object', 'weight': 5},
#   'saints': {'type': 'object', 'weight': 1115},
#   'substance things': {'type': 'subject', 'weight': 1},
#   'things God': {'type': 'subject', 'weight': 113},
#   'poles': {'type': 'object', 'weight': 9},
#   'etc': {'type': 'object', 'weight': 109},
#   'person': {'type': 'object', 'weight': 5095},
#   'heavens': {'type': 'object', 'weight': 234},
#   'providence': {'type': 'object', 'weight': 658},
#   'Ghost': {'type': 'object', 'weight': 3003},
#   'divinity': {'type': 'object', 'weight': 23},
#   'self': {'type': 'object', 'weight': 118},
#   'places': {'type': 'object', 'weight': 269},
#   'forasmuch man': {'type': 'subject', 'weight': 4},
#   'teeth': {'type': 'object', 'weight': 19},
#   'supposition': {'type': 'object', 'weight': 111},
#   'grain': {'type': 'subject', 'weight': 20},
#   'millet': {'type': 'object', 'weight': 1},
#   'blackness': {'type': 'object', 'weight': 11},
#   'I:3:7': {'type': 'object', 'weight': 13},
#   'plenitude': {'type': 'object', 'weight': 43},
#   'ancients': {'type': 'object', 'weight': 118},
#   'Nat': {'type': 'object', 'weight': 34},
#   'God creature': {'type': 'subject', 'weight': 20},
#   'production': {'type': 'subject', 'weight': 299},
#   'privation': {'type': 'object', 'weight': 210},
#   'regards': {'type': 'object', 'weight': 131},
#   'matter form': {'type': 'subject', 'weight': 4},
#   'bodies subject': {'type': 'subject', 'weight': 7},
#   'locality': {'type': 'object', 'weight': 8},
#   'substances': {'type': 'object', 'weight': 602},
#   'forasmuch': {'type': 'subject', 'weight': 52},
#   'kinds': {'type': 'subject', 'weight': 661},
#   'Dionysius substances': {'type': 'subject', 'weight': 46},
#   'choice': {'type': 'object', 'weight': 454},
#   'variation': {'type': 'object', 'weight': 16},
#   'evil': {'type': 'object', 'weight': 2557},
#   'Damascene': {'type': 'subject', 'weight': 857},
#   'I:8:2': {'type': 'object', 'weight': 7},
#   'powers': {'type': 'object', 'weight': 1763},
#   'creatures power God': {'type': 'subject', 'weight': 3},
#   'succession': {'type': 'subject', 'weight': 185},
#   'bereft': {'type': 'object', 'weight': 16},
#   'numbering': {'type': 'object', 'weight': 1},
#   'uniformity': {'type': 'object', 'weight': 21},
#   'apprehension': {'type': 'object', 'weight': 423},
#   'sources': {'type': 'object', 'weight': 65},
#   'eternity': {'type': 'object', 'weight': 281},
#   'Athanasius': {'type': 'subject', 'weight': 363},
#   'Creed': {'type': 'object', 'weight': 18},
#   'Father Son Ghost idea': {'type': 'subject', 'weight': 4},
#   'immutability': {'type': 'object', 'weight': 16},
#   'Jerome God': {'type': 'subject', 'weight': 50},
#   'God Eternity': {'type': 'subject', 'weight': 2},
#   'vision': {'type': 'object', 'weight': 806},
#   'corruptible': {'type': 'object', 'weight': 22},
#   'I:9:1': {'type': 'object', 'weight': 14},
#   'hills': {'type': 'object', 'weight': 12},
#   'fruits': {'type': 'object', 'weight': 222},
#   'length': {'type': 'object', 'weight': 152},
#   'Word': {'type': 'object', 'weight': 1514},
#   'duration': {'type': 'object', 'weight': 113},
#   'earth': {'type': 'object', 'weight': 800},
#   'Saints': {'type': 'object', 'weight': 32},
#   'text': {'type': 'object', 'weight': 489},
#   'Eternity time time': {'type': 'subject', 'weight': 4},
#   'eternity time': {'type': 'subject', 'weight': 4},
#   'Boethius': {'type': 'subject', 'weight': 374},
#   'Consol': {'type': 'object', 'weight': 12},
#   'v': {'type': 'subject', 'weight': 174},
#   'measures': {'type': 'object', 'weight': 21},
#   'revolution': {'type': 'object', 'weight': 4},
#   'potentialities': {'type': 'object', 'weight': 4},
#   'year': {'type': 'object', 'weight': 131},
#   'day': {'type': 'object', 'weight': 920},
#   'aeviternity': {'type': 'object', 'weight': 21},
#   'Aeviternity': {'type': 'subject', 'weight': 12},
#   'mean': {'type': 'object', 'weight': 392},
#   'eternity difference': {'type': 'subject', 'weight': 4},
#   'eternity time aeviternity theory': {'type': 'subject', 'weight': 16},
#   'contradiction': {'type': 'object', 'weight': 175},
#   'innovation': {'type': 'object', 'weight': 14},
#   'receding': {'type': 'object', 'weight': 2},
#   'incongruity': {'type': 'subject', 'weight': 30},
#   'changeableness': {'type': 'object', 'weight': 30},
#   'fact thing': {'type': 'subject', 'weight': 2},
#   'changelessness': {'type': 'object', 'weight': 1},
#   'measure eternity': {'type': 'subject', 'weight': 4},
#   'permanence': {'type': 'object', 'weight': 22},
#   'change': {'type': 'object', 'weight': 728},
#   'movements': {'type': 'subject', 'weight': 989},
#   'affections': {'type': 'object', 'weight': 443},
#   'Aeviternity time': {'type': 'subject', 'weight': 2},
#   'ells': {'type': 'object', 'weight': 3},
#   'cloth': {'type': 'object', 'weight': 19},
#   'unity durations': {'type': 'subject', 'weight': 26},
#   'unity': {'type': 'object', 'weight': 904},
#   'diversity': {'type': 'object', 'weight': 499},
#   'influx': {'type': 'object', 'weight': 14},
#   'time measure forasmuch': {'type': 'subject', 'weight': 4},
#   'reasons': {'type': 'object', 'weight': 964},
#   'reason time': {'type': 'subject', 'weight': 6},
#   'oneness': {'type': 'object', 'weight': 67},
#   'equality': {'type': 'object', 'weight': 414},
#   'Origen': {'type': 'subject', 'weight': 447},
#   'Archon': {'type': 'object', 'weight': 11},
#   'element': {'type': 'object', 'weight': 171},
#   'present': {'type': 'object', 'weight': 168},
#   'reality': {'type': 'object', 'weight': 396},
#   'undivision': {'type': 'object', 'weight': 10},
#   'indivisibility': {'type': 'object', 'weight': 25},
#   'undivided': {'type': 'subject', 'weight': 1},
#   'God reason thing': {'type': 'subject', 'weight': 1},
#   'simplicity': {'type': 'object', 'weight': 105},
#   'Socrates': {'type': 'subject', 'weight': 242},
#   'I:3:3': {'type': 'object', 'weight': 6},
#   'God Gods': {'type': 'subject', 'weight': 9},
#   'gods perfection gods philosophers': {'type': 'subject', 'weight': 50},
#   'thereto': {'type': 'object', 'weight': 411},
#   'Bernard': {'type': 'subject', 'weight': 75},
#   'subsistent': {'type': 'subject', 'weight': 12},
#   'bat': {'type': 'object', 'weight': 158},
#   'account': {'type': 'object', 'weight': 3103},
#   'excess': {'type': 'object', 'weight': 278},
#   'intellect opinion beatitude': {'type': 'subject', 'weight': 18},
#   'function': {'type': 'object', 'weight': 23},
#   'beatitude': {'type': 'subject', 'weight': 542},
#   'wonder': {'type': 'object', 'weight': 72},
#   'desire': {'type': 'object', 'weight': 1005},
#   'desire blessed': {'type': 'subject', 'weight': 6},
#   'glass': {'type': 'object', 'weight': 39},
#   'enigma': {'type': 'object', 'weight': 6},
#   'seer': {'type': 'object', 'weight': 45},
#   'similitude substance principle': {'type': 'subject', 'weight': 6},
#   'eye': {'type': 'object', 'weight': 309},
#   'stone': {'type': 'object', 'weight': 212},
#   'similitudes': {'type': 'object', 'weight': 51},
#   'Psalm': {'type': 'object', 'weight': 549},
#   'organ': {'type': 'object', 'weight': 221},
#   'I:3:1': {'type': 'object', 'weight': 2},
#   'grace life': {'type': 'subject', 'weight': 19},
#   'knower': {'type': 'object', 'weight': 113},
#   'knowledge mode': {'type': 'subject', 'weight': 72},
#   'natures': {'type': 'object', 'weight': 507},
#   'singular': {'type': 'object', 'weight': 69},
#   'therefrom': {'type': 'object', 'weight': 169},
#   'creature intellect': {'type': 'subject', 'weight': 4},
#   'disposition': {'type': 'object', 'weight': 1562},
#   'height': {'type': 'object', 'weight': 80},
#   'understanding': {'type': 'object', 'weight': 1026},
#   'Apocalypse': {'type': 'object', 'weight': 65},
#   'illumination': {'type': 'object', 'weight': 17},
#   'saying': {'type': 'object', 'weight': 447},
#   'John': {'type': 'object', 'weight': 869},
#   'Star': {'type': 'subject', 'weight': 12},
#   'star': {'type': 'object', 'weight': 361},
#   'intellect faculty': {'type': 'subject', 'weight': 64},
#   'deiformity': {'type': 'object', 'weight': 8},
#   'intellect desire': {'type': 'subject', 'weight': 64},
#   'apt': {'type': 'object', 'weight': 8},
#   'charity': {'type': 'object', 'weight': 3054},
#   'answer': {'type': 'subject', 'weight': 129},
#   'counsel': {'type': 'object', 'weight': 605},
#   'thought': {'type': 'object', 'weight': 302},
#   'hosts': {'type': 'object', 'weight': 33},
#   'Verb': {'type': 'object', 'weight': 37},
#   'triangle': {'type': 'subject', 'weight': 37},
#   'angles': {'type': 'object', 'weight': 68},
#   'God intellect': {'type': 'subject', 'weight': 34},
#   'ignorance': {'type': 'object', 'weight': 775},
#   'whosoever': {'type': 'subject', 'weight': 111},
#   'things effects': {'type': 'subject', 'weight': 36},
#   'conclusions': {'type': 'object', 'weight': 337},
#   'intellect God God': {'type': 'subject', 'weight': 3},
#   'image': {'type': 'object', 'weight': 625},
#   'glance': {'type': 'object', 'weight': 135},
#   'whereof': {'type': 'object', 'weight': 161},
#   'Man gloss': {'type': 'subject', 'weight': 30},
#   'images': {'type': 'object', 'weight': 216},
#   'reason mode': {'type': 'subject', 'weight': 8},
#   'I:2:9': {'type': 'object', 'weight': 4},
#   'dreams': {'type': 'object', 'weight': 74},
#   'events': {'type': 'object', 'weight': 543},
#   'supreme': {'type': 'object', 'weight': 6},
#   'relationship creatures': {'type': 'subject', 'weight': 16},
#   'defect': {'type': 'object', 'weight': 748},
#   'Apostle hath': {'type': 'subject', 'weight': 27},
#   'princes': {'type': 'object', 'weight': 232},
#   'spirit': {'type': 'object', 'weight': 858},
#   'infusion': {'type': 'object', 'weight': 163},
#   'imagination': {'type': 'object', 'weight': 320},
#   'visions': {'type': 'object', 'weight': 44},
#   'Baptism': {'type': 'object', 'weight': 1414},
#   'dove': {'type': 'object', 'weight': 182},
#   'conceptions': {'type': 'object', 'weight': 36},
#   'shape': {'type': 'object', 'weight': 128},
#   'Father': {'type': 'object', 'weight': 1591},
#   'Lord Almighty': {'type': 'subject', 'weight': 4},
#   'war': {'type': 'object', 'weight': 145},
#   'conception': {'type': 'object', 'weight': 414},
#   'I:12:11': {'type': 'object', 'weight': 12},
#   'excellence': {'type': 'object', 'weight': 577},
#   'names': {'type': 'subject', 'weight': 627},
#   'remotion': {'type': 'object', 'weight': 10},
#   'distance': {'type': 'object', 'weight': 126},
#   'Moses': {'type': 'object', 'weight': 505},
#   'relationship': {'type': 'object', 'weight': 353},
#   'opinions': {'type': 'object', 'weight': 446},
#   'words God God': {'type': 'subject', 'weight': 4},
#   'matter names': {'type': 'subject', 'weight': 72},
#   'health': {'type': 'object', 'weight': 501},
#   'medicine': {'type': 'object', 'weight': 212},
#   'representation': {'type': 'object', 'weight': 100},
#   'intellects intellect': {'type': 'subject', 'weight': 4},
#   'principle effects': {'type': 'subject', 'weight': 4},
#   'creatures God meaning God': {'type': 'subject', 'weight': 1},
#   'God meaning': {'type': 'subject', 'weight': 12},
#   'Doctr': {'type': 'object', 'weight': 29},
#   'Ambrose names': {'type': 'subject', 'weight': 99},
#   'majesty': {'type': 'object', 'weight': 35},
#   'perfections intellect': {'type': 'subject', 'weight': 72},
#   'viz': {'type': 'object', 'weight': 161},
#   'synonyms united': {'type': 'subject', 'weight': 1},
#   'clothing': {'type': 'object', 'weight': 26},
#   'meanings': {'type': 'object', 'weight': 6},
#   'Articles': {'type': 'object', 'weight': 277},
#   'solution': {'type': 'object', 'weight': 87},
#   'aspects': {'type': 'object', 'weight': 79},
#   'terms': {'type': 'subject', 'weight': 592},
#   'wisdom genus': {'type': 'subject', 'weight': 3},
#   'God creatures distance': {'type': 'subject', 'weight': 1},
#   'predication': {'type': 'subject', 'weight': 55},
#   'predication reason effect': {'type': 'subject', 'weight': 50},
#   'distinct': {'type': 'object', 'weight': 27},
#   'exercise': {'type': 'object', 'weight': 204},
#   'manifold': {'type': 'object', 'weight': 14},
#   'circumscribes': {'type': 'object', 'weight': 2},
#   'reasoning': {'type': 'object', 'weight': 66},
#   'fallacy': {'type': 'object', 'weight': 8},
#   'equivocation': {'type': 'object', 'weight': 12},
#   'healthy': {'type': 'object', 'weight': 21},
#   'equivocal': {'type': 'object', 'weight': 3},
#   'mode idea term': {'type': 'subject', 'weight': 28},
#   'proportions': {'type': 'object', 'weight': 7},
#   'community': {'type': 'object', 'weight': 366},
#   'analogies': {'type': 'object', 'weight': 2},
#   'sign': {'type': 'object', 'weight': 477},
#   'equivocals': {'type': 'object', 'weight': 2},
#   'urine': {'type': 'object', 'weight': 29},
#   'univocals': {'type': 'object', 'weight': 2},
#   'animals': {'type': 'object', 'weight': 1061},
#   'field': {'type': 'object', 'weight': 49},
#   'lion': {'type': 'object', 'weight': 68},
#   'flowering': {'type': 'object', 'weight': 2},
#   'beauty': {'type': 'object', 'weight': 241},
#   'smile': {'type': 'object', 'weight': 2},
#   'strength': {'type': 'object', 'weight': 315},
#   'imposition': {'type': 'object', 'weight': 141},
#   'extremes': {'type': 'object', 'weight': 84},
#   'relation order': {'type': 'subject', 'weight': 66},
#   'relations': {'type': 'object', 'weight': 758},
#   'habitude': {'type': 'object', 'weight': 43},
#   'extreme': {'type': 'object', 'weight': 28},
#   'extremes sense': {'type': 'subject', 'weight': 12},
#   'perception': {'type': 'object', 'weight': 57},
#   'inasmuch intellect': {'type': 'subject', 'weight': 3},
#   'right': {'type': 'object', 'weight': 747},
#   'column': {'type': 'object', 'weight': 8},
#   'relation God': {'type': 'subject', 'weight': 4},
#   'creation': {'type': 'object', 'weight': 496},
#   'Ambrose God': {'type': 'subject', 'weight': 52},
#   'signifies': {'type': 'subject', 'weight': 160},
#   'properties': {'type': 'object', 'weight': 261},
#   'source': {'type': 'subject', 'weight': 213},
#   'Dionysius Deity': {'type': 'subject', 'weight': 15},
#   'courage': {'type': 'object', 'weight': 57},
#   'names form': {'type': 'subject', 'weight': 9},
#   'subjects': {'type': 'object', 'weight': 354},
#   'reason mind': {'type': 'subject', 'weight': 204},
#   'plurality': {'type': 'object', 'weight': 91},
#   'Achilles': {'type': 'object', 'weight': 12},
#   'abstraction': {'type': 'object', 'weight': 108},
#   'individuals': {'type': 'object', 'weight': 227},
#   'rules': {'type': 'subject', 'weight': 152},
#   'I:11:3': {'type': 'object', 'weight': 8},
#   'Gods': {'type': 'object', 'weight': 1},
#   'Hebrew': {'type': 'object', 'weight': 9},
#   'Tetragrammaton': {'type': 'object', 'weight': 9},
#   'Herm': {'type': 'object', 'weight': 9},
#   'picture': {'type': 'object', 'weight': 7},
#   'heathen': {'type': 'subject', 'weight': 8},
#   'idol': {'type': 'subject', 'weight': 19},
#   'Deity': {'type': 'object', 'weight': 41},
#   'Catholic': {'type': 'subject', 'weight': 30},
#   'significations': {'type': 'object', 'weight': 19},
#   'issue': {'type': 'object', 'weight': 142},
#   'god': {'type': 'object', 'weight': 54},
#   'remark': {'type': 'subject', 'weight': 31},
#   'Moses Lord thou': {'type': 'subject', 'weight': 176},
#   'universality': {'type': 'object', 'weight': 68},
#   'God names': {'type': 'subject', 'weight': 2},
#   'sea': {'type': 'object', 'weight': 118},
#   'consignification': {'type': 'object', 'weight': 9},
#   'ocean': {'type': 'object', 'weight': 14},
#   'past': {'type': 'object', 'weight': 144},
#   'propositions God': {'type': 'subject', 'weight': 12},
#   'propositions': {'type': 'object', 'weight': 73},
#   'man thing': {'type': 'subject', 'weight': 102},
#   'predicates': {'type': 'subject', 'weight': 8},
#   'identity': {'type': 'object', 'weight': 67},
#   'riches': {'type': 'object', 'weight': 286},
#   'amplitude': {'type': 'object', 'weight': 2},
#   'Philosopher soul': {'type': 'subject', 'weight': 39},
#   'contraction': {'type': 'subject', 'weight': 63},
#   'immateriality': {'type': 'subject', 'weight': 51},
#   'ii': {'type': 'object', 'weight': 797},
#   'plants sense': {'type': 'subject', 'weight': 8},
#   'iii': {'type': 'object', 'weight': 765},
#   'operation Philosopher': {'type': 'subject', 'weight': 2},
#   'sensible intelligible': {'type': 'subject', 'weight': 8},
#   'God intellect case': {'type': 'subject', 'weight': 6},
#   'Augustine God God': {'type': 'subject', 'weight': 80},
#   'I:1:2': {'type': 'object', 'weight': 6},
#   'vii': {'type': 'subject', 'weight': 286},
#   'act Philosopher': {'type': 'subject', 'weight': 12},
#   'potentiality act': {'type': 'subject', 'weight': 74},
#   'essence act': {'type': 'subject', 'weight': 6},
#   'object act': {'type': 'subject', 'weight': 39},
#   'multiplicity': {'type': 'object', 'weight': 55},
#   'subsists': {'type': 'object', 'weight': 25},
#   'eyes': {'type': 'object', 'weight': 340},
#   'mirror': {'type': 'object', 'weight': 66},
#   'joints': {'type': 'object', 'weight': 20},
#   'perfect': {'type': 'object', 'weight': 525},
#   'understanding God': {'type': 'subject', 'weight': 36},
#   'examples': {'type': 'object', 'weight': 286},
#   'lines': {'type': 'object', 'weight': 142},
#   'colors': {'type': 'object', 'weight': 99},
#   'position': {'type': 'object', 'weight': 215},
#   'causality': {'type': 'object', 'weight': 117},
#   'living': {'type': 'object', 'weight': 276},
#   'intelligent': {'type': 'object', 'weight': 16},
#   'essences': {'type': 'object', 'weight': 19},
#   'common': {'type': 'object', 'weight': 57},
#   'proper': {'type': 'object', 'weight': 13},
#   'circle': {'type': 'object', 'weight': 72},
#   'modes': {'type': 'object', 'weight': 54},
#   'God things': {'type': 'subject', 'weight': 4},
#   'particularity': {'type': 'object', 'weight': 6},
#   'discursion': {'type': 'object', 'weight': 33},
#   'unknown': {'type': 'object', 'weight': 42},
#   'second': {'type': 'subject', 'weight': 1498},
#   'discursion God': {'type': 'subject', 'weight': 8},
#   'spiritual': {'type': 'object', 'weight': 53},
#   'knowledge artificer': {'type': 'subject', 'weight': 14},
#   'art': {'type': 'object', 'weight': 573},
#   'artificer': {'type': 'object', 'weight': 33},
#   'form heat': {'type': 'subject', 'weight': 11},
#   'heating': {'type': 'object', 'weight': 185},
#   'far': {'type': 'object', 'weight': 369},
#   'inclination form inasmuch': {'type': 'subject', 'weight': 24},
#   'Philosopher God': {'type': 'subject', 'weight': 12},
#   'approbation': {'type': 'object', 'weight': 6},
#   'reason God': {'type': 'subject', 'weight': 33},
#   'future': {'type': 'object', 'weight': 380},
#   'God futurity': {'type': 'subject', 'weight': 2},
#   'Hell': {'type': 'subject', 'weight': 28},
#   'corruption God': {'type': 'subject', 'weight': 8},
#   'darkness': {'type': 'object', 'weight': 266},
#   'Empedocles': {'type': 'object', 'weight': 23},
#   'discord': {'type': 'object', 'weight': 79},
#   'universal': {'type': 'object', 'weight': 125},
#   'eclipses': {'type': 'object', 'weight': 16},
#   'astrologer': {'type': 'object', 'weight': 16},
#   'Sophroniscus': {'type': 'object', 'weight': 16},
#   'singularity': {'type': 'object', 'weight': 20},
#   'application': {'type': 'object', 'weight': 245},
#   'particular': {'type': 'object', 'weight': 73},
#   'knowledge causality power': {'type': 'subject', 'weight': 32},
#   'I:44:2': {'type': 'object', 'weight': 30},
#   'Augustine Civ': {'type': 'subject', 'weight': 300},
#   'bounds': {'type': 'object', 'weight': 116},
#   'knowledge world generation': {'type': 'subject', 'weight': 18},
#   'hearts': {'type': 'object', 'weight': 273},
#   'creatures reason': {'type': 'subject', 'weight': 36},
#   'individual': {'type': 'object', 'weight': 802},
#   'particulars': {'type': 'object', 'weight': 21},
#   'reason species essence intellect': {'type': 'subject', 'weight': 60},
#   'works God': {'type': 'subject', 'weight': 12},
#   'evidence': {'type': 'object', 'weight': 244},
#   'contingent': {'type': 'object', 'weight': 23},
#   'I:10:2': {'type': 'object', 'weight': 2},
#   'types': {'type': 'object', 'weight': 150},
#   'presentiality': {'type': 'object', 'weight': 10},
#   'antecedent': {'type': 'subject', 'weight': 38},
#   'antecedent Philosopher': {'type': 'subject', 'weight': 8},
#   'objection': {'type': 'object', 'weight': 77},
#   'thing distinction': {'type': 'subject', 'weight': 12},
#   'crow': {'type': 'subject', 'weight': 8},
#   'objection words': {'type': 'subject', 'weight': 84},
#   'enunciations': {'type': 'object', 'weight': 33},
#   'forthwith': {'type': 'subject', 'weight': 128},
#   'enunciation': {'type': 'object', 'weight': 21},
#   'knowledge substance': {'type': 'subject', 'weight': 6},
#   'knowledge Philosopher': {'type': 'subject', 'weight': 6},
#   'Metaphysics': {'type': 'object', 'weight': 28},
#   'builder': {'type': 'subject', 'weight': 233},
#   'speculative': {'type': 'object', 'weight': 34},
#   'end builder': {'type': 'subject', 'weight': 50},
#   'period': {'type': 'object', 'weight': 35},
#   'sicknesses': {'type': 'subject', 'weight': 30},
#   'physician': {'type': 'object', 'weight': 487},
#   'nobility': {'type': 'object', 'weight': 16},
#   'Augustine xlvi),"Such': {'type': 'subject', 'weight': 12},
#   'Idea': {'type': 'subject', 'weight': 15},
#   'forma': {'type': 'object', 'weight': 2},
#   'chance': {'type': 'object', 'weight': 146},
#   'ends': {'type': 'object', 'weight': 156},
#   'form agent': {'type': 'subject', 'weight': 4},
#   'agents': {'type': 'object', 'weight': 150},
#   'notion': {'type': 'subject', 'weight': 634},
#   'Augustine Ideas': {'type': 'subject', 'weight': 36},
#   'end order good': {'type': 'subject', 'weight': 6},
#   'general': {'type': 'object', 'weight': 34},
#   'type': {'type': 'object', 'weight': 335},
#   'imitation': {'type': 'object', 'weight': 30},
#   'Ideas': {'type': 'subject', 'weight': 2},
#   'Plato': {'type': 'object', 'weight': 257},
#   'office': {'type': 'object', 'weight': 540},
#   'exemplar': {'type': 'object', 'weight': 108},
#   'making': {'type': 'object', 'weight': 25},
#   'appetite intellect': {'type': 'subject', 'weight': 2},
#   'knowledge thing': {'type': 'subject', 'weight': 2},
#   'appetite desirer': {'type': 'subject', 'weight': 3},
#   'object true': {'type': 'subject', 'weight': 6},
#   'true': {'type': 'object', 'weight': 58},
#   'pass': {'type': 'subject', 'weight': 7},
#   'preconception': {'type': 'object', 'weight': 12},
#   'Augustine Truth Hilary Truth': {'type': 'subject', 'weight': 20},
#   'Truth viii truth': {'type': 'subject', 'weight': 6},
#   'unlikeness': {'type': 'object', 'weight': 22},
#   'conformity': {'type': 'object', 'weight': 129},
#   'comparison': {'type': 'object', 'weight': 576},
#   'Truth': {'type': 'subject', 'weight': 143},
#   'soul good good': {'type': 'subject', 'weight': 3},
#   'desirable': {'type': 'object', 'weight': 1},
#   'mathematics': {'type': 'object', 'weight': 8},
#   'true regards nature': {'type': 'subject', 'weight': 3},
#   'regards good': {'type': 'subject', 'weight': 1},
#   'truth things': {'type': 'subject', 'weight': 40},
#   'children': {'type': 'object', 'weight': 2390},
#   'face': {'type': 'object', 'weight': 213},
#   'intellects': {'type': 'object', 'weight': 79},
#   'entity': {'type': 'object', 'weight': 2},
#   'essences truth': {'type': 'subject', 'weight': 3},
#   'I:10:3': {'type': 'object', 'weight': 2},
#   'intellect truth intellect truth': {'type': 'subject', 'weight': 1},
#   'God truth': {'type': 'subject', 'weight': 1},
#   'false': {'type': 'object', 'weight': 4},
#   'truth intellect': {'type': 'subject', 'weight': 8},
#   'falsity': {'type': 'object', 'weight': 82},
#   'Augustine body': {'type': 'subject', 'weight': 17},
#   'falsity opposites': {'type': 'subject', 'weight': 36},
#   'se': {'type': 'object', 'weight': 76},
#   'ordinance': {'type': 'object', 'weight': 111},
#   'human': {'type': 'object', 'weight': 189},
#   'vanity': {'type': 'object', 'weight': 87},
#   'quality': {'type': 'object', 'weight': 344},
#   'Scriptures': {'type': 'object', 'weight': 179},
#   'deeds': {'type': 'object', 'weight': 585},
#   'sin': {'type': 'object', 'weight': 9193},
#   'diameter Philosopher Augustine tragedian': {'type': 'subject',
#    'weight': 35},
#   'appearances': {'type': 'object', 'weight': 11},
#   'rise': {'type': 'object', 'weight': 109},
#   'gall Augustine': {'type': 'subject', 'weight': 6},
#   'occasion': {'type': 'object', 'weight': 120},
#   'resemblance': {'type': 'subject', 'weight': 64},
#   'instances': {'type': 'object', 'weight': 68},
#   'majority': {'type': 'object', 'weight': 129},
#   'Augustine senses': {'type': 'subject', 'weight': 8},
#   'error': {'type': 'object', 'weight': 490},
#   'Falsity': {'type': 'subject', 'weight': 3},
#   'truth senses': {'type': 'subject', 'weight': 36},
#   'I:16:2': {'type': 'object', 'weight': 6},
#   'apprehending': {'type': 'object', 'weight': 2},
#   'knowledge likeness': {'type': 'subject', 'weight': 108},
#   'indisposition': {'type': 'object', 'weight': 138},
#   'sweet': {'type': 'object', 'weight': 14},
#   'impressions': {'type': 'object', 'weight': 73},
#   'judgment': {'type': 'object', 'weight': 2202},
#   'composition truth': {'type': 'subject', 'weight': 2},
#   'qualities': {'type': 'object', 'weight': 324},
#   'feet': {'type': 'object', 'weight': 217},
#   'sensible': {'type': 'object', 'weight': 73},
#   'affirming': {'type': 'object', 'weight': 7},
#   'sensibles': {'type': 'object', 'weight': 58},
#   'judging': {'type': 'object', 'weight': 166},
#   'intellect falsity': {'type': 'subject', 'weight': 24},
#   'statement animals intellect': {'type': 'subject', 'weight': 3},
#   'Philosopher opinion': {'type': 'subject', 'weight': 15},
#   'affirmation': {'type': 'object', 'weight': 109},
#   'contraries': {'type': 'object', 'weight': 123},
#   'negation': {'type': 'subject', 'weight': 184},
#   'blindness': {'type': 'object', 'weight': 108},
#   'Contraries': {'type': 'subject', 'weight': 8},
#   'color': {'type': 'object', 'weight': 181},
#   'Philosopher iv': {'type': 'subject', 'weight': 9},
#   'plants': {'type': 'object', 'weight': 138},
#   'life bodies': {'type': 'subject', 'weight': 6},
#   'things life': {'type': 'subject', 'weight': 59},
#   'Vegetab': {'type': 'object', 'weight': 2},
#   'animal movement': {'type': 'subject', 'weight': 14},
#   'cognizance': {'type': 'object', 'weight': 23},
#   'appearance': {'type': 'object', 'weight': 130},
#   'dimensions': {'type': 'object', 'weight': 105},
#   'abstract': {'type': 'object', 'weight': 74},
#   'Philosopher ix': {'type': 'subject', 'weight': 8},
#   'Life': {'type': 'subject', 'weight': 41},
#   'executing': {'type': 'object', 'weight': 3},
#   'instrument': {'type': 'object', 'weight': 276},
#   'growth': {'type': 'object', 'weight': 96},
#   'animals principle': {'type': 'subject', 'weight': 4},
#   'perfect movement': {'type': 'subject', 'weight': 33},
#   'touch': {'type': 'object', 'weight': 339},
# ...
#    'to': 'Dionysius'},
#   'perfection_argument': {'weight': 3, 'from': 'perfection', 'to': 'argument'},
#   'God_limitation': {'weight': 4, 'from': 'God', 'to': 'limitation'},
#   'God_mode': {'weight': 51, 'from': 'God', 'to': 'mode'},
#   'agent_manner': {'weight': 2, 'from': 'agent', 'to': 'manner'},
#   'effect_species': {'weight': 8, 'from': 'effect', 'to': 'species'},
#   'effect_formality': {'weight': 7, 'from': 'effect', 'to': 'formality'},
#   'effect_form': {'weight': 12, 'from': 'effect', 'to': 'form'},
#   'effect_agent': {'weight': 16, 'from': 'effect', 'to': 'agent'},
#   'effect_effect': {'weight': 26, 'from': 'effect', 'to': 'effect'},
#   'man_species': {'weight': 52, 'from': 'man', 'to': 'species'},
#   'man_formality': {'weight': 3, 'from': 'man', 'to': 'formality'},
#   'man_man': {'weight': 499, 'from': 'man', 'to': 'man'},
#   'things_sort': {'weight': 5, 'from': 'things', 'to': 'sort'},
#   'things_likeness': {'weight': 16, 'from': 'things', 'to': 'likeness'},
#   'things_form': {'weight': 50, 'from': 'things', 'to': 'form'},
#   'things_genus': {'weight': 25, 'from': 'things', 'to': 'genus'},
#   'things_heat': {'weight': 4, 'from': 'things', 'to': 'heat'},
#   'things_sun': {'weight': 6, 'from': 'things', 'to': 'sun'},
#   'effect_sort': {'weight': 3, 'from': 'effect', 'to': 'sort'},
#   'effect_likeness': {'weight': 3, 'from': 'effect', 'to': 'likeness'},
#   'effect_analogy': {'weight': 3, 'from': 'effect', 'to': 'analogy'},
#   'existence_way': {'weight': 1, 'from': 'existence', 'to': 'way'},
#   'existence_things': {'weight': 4, 'from': 'existence', 'to': 'things'},
#   'existence_principle': {'weight': 1, 'from': 'existence', 'to': 'principle'},
#   'Damascene God philosophers_principle': {'weight': 5,
#    'from': 'Damascene God philosophers',
#    'to': 'principle'},
#   'Damascene God philosophers_reason': {'weight': 5,
#    'from': 'Damascene God philosophers',
#    'to': 'reason'},
#   'Damascene God philosophers_infinitude': {'weight': 5,
#    'from': 'Damascene God philosophers',
#    'to': 'infinitude'},
#   'things_consequence': {'weight': 4, 'from': 'things', 'to': 'consequence'},
#   'things_principle': {'weight': 29, 'from': 'things', 'to': 'principle'},
#   'things_infinity': {'weight': 4, 'from': 'things', 'to': 'infinity'},
#   'things_nature': {'weight': 134, 'from': 'things', 'to': 'nature'},
#   'matter_principle': {'weight': 4, 'from': 'matter', 'to': 'principle'},
#   'matter_infinity': {'weight': 1, 'from': 'matter', 'to': 'infinity'},
#   'matter_effect': {'weight': 7, 'from': 'matter', 'to': 'effect'},
#   'body_things': {'weight': 23, 'from': 'body', 'to': 'things'},
#   'matter_matter': {'weight': 60, 'from': 'matter', 'to': 'matter'},
#   'matter_form': {'weight': 69, 'from': 'matter', 'to': 'form'},
#   'matter_way': {'weight': 22, 'from': 'matter', 'to': 'way'},
#   'matter_forms': {'weight': 17, 'from': 'matter', 'to': 'forms'},
#   'matter_thing': {'weight': 6, 'from': 'matter', 'to': 'thing'},
#   'infinite_hand': {'weight': 2, 'from': 'infinite', 'to': 'hand'},
#   'infinite_matter': {'weight': 11, 'from': 'infinite', 'to': 'matter'},
#   'infinite_nature': {'weight': 7, 'from': 'infinite', 'to': 'nature'},
#   'infinite_I:3:4': {'weight': 5, 'from': 'infinite', 'to': 'I:3:4'},
#   'infinite_things': {'weight': 5, 'from': 'infinite', 'to': 'things'},
#   'infinite_form': {'weight': 5, 'from': 'infinite', 'to': 'form'},
#   'God_Reply': {'weight': 2, 'from': 'God', 'to': 'Reply'},
#   'God_Objection': {'weight': 6, 'from': 'God', 'to': 'Objection'},
#   'infinite_principle': {'weight': 2, 'from': 'infinite', 'to': 'principle'},
#   'infinite_beginning': {'weight': 2, 'from': 'infinite', 'to': 'beginning'},
#   'infinite_God': {'weight': 2, 'from': 'infinite', 'to': 'God'},
#   'infinite_Phys': {'weight': 2, 'from': 'infinite', 'to': 'Phys'},
#   'Things_regard': {'weight': 5, 'from': 'Things', 'to': 'regard'},
#   'Things_God': {'weight': 5, 'from': 'Things', 'to': 'God'},
#   'Things_form': {'weight': 5, 'from': 'Things', 'to': 'form'},
#   'matter_example': {'weight': 9, 'from': 'matter', 'to': 'example'},
#   'wood_form': {'weight': 3, 'from': 'wood', 'to': 'form'},
#   'wood_infinite': {'weight': 3, 'from': 'wood', 'to': 'infinite'},
#   'wood_number': {'weight': 3, 'from': 'wood', 'to': 'number'},
#   'wood_potentiality': {'weight': 3, 'from': 'wood', 'to': 'potentiality'},
#   'wood_shapes': {'weight': 3, 'from': 'wood', 'to': 'shapes'},
#   'wood_reference': {'weight': 3, 'from': 'wood', 'to': 'reference'},
#   'things forms_way': {'weight': 4, 'from': 'things forms', 'to': 'way'},
#   'things forms_matter': {'weight': 4, 'from': 'things forms', 'to': 'matter'},
#   'case_forms': {'weight': 3, 'from': 'case', 'to': 'forms'},
#   'case_angels': {'weight': 3, 'from': 'case', 'to': 'angels'},
#   'case_matter': {'weight': 10, 'from': 'case', 'to': 'matter'},
#   'form_nature': {'weight': 47, 'from': 'form', 'to': 'nature'},
#   'body surface bodies_body': {'weight': 4,
#    'from': 'body surface bodies',
#    'to': 'body'},
#   'body surface bodies_surface': {'weight': 4,
#    'from': 'body surface bodies',
#    'to': 'surface'},
#   'body surface bodies_magnitude': {'weight': 4,
#    'from': 'body surface bodies',
#    'to': 'magnitude'},
#   'body surface bodies_line': {'weight': 4,
#    'from': 'body surface bodies',
#    'to': 'line'},
#   'body surface bodies_essence': {'weight': 4,
#    'from': 'body surface bodies',
#    'to': 'essence'},
#   'body_fire': {'weight': 9, 'from': 'body', 'to': 'fire'},
#   'body_species': {'weight': 34, 'from': 'body', 'to': 'species'},
#   'body_matter': {'weight': 51, 'from': 'body', 'to': 'matter'},
#   'body_form': {'weight': 37, 'from': 'body', 'to': 'form'},
#   'body_infinite': {'weight': 4, 'from': 'body', 'to': 'infinite'},
#   'body_magnitude': {'weight': 11, 'from': 'body', 'to': 'magnitude'},
#   'body_premises': {'weight': 4, 'from': 'body', 'to': 'premises'},
#   'body_essence': {'weight': 14, 'from': 'body', 'to': 'essence'},
#   'body_individuality': {'weight': 4, 'from': 'body', 'to': 'individuality'},
#   'creature_essence': {'weight': 6, 'from': 'creature', 'to': 'essence'},
#   'creature_quantity': {'weight': 3, 'from': 'creature', 'to': 'quantity'},
#   'creature_matter': {'weight': 7, 'from': 'creature', 'to': 'matter'},
#   'creature_respect': {'weight': 15, 'from': 'creature', 'to': 'respect'},
#   'creature_magnitude': {'weight': 3, 'from': 'creature', 'to': 'magnitude'},
#   'creature_ways': {'weight': 3, 'from': 'creature', 'to': 'ways'},
#   'accidents_form': {'weight': 3, 'from': 'accidents', 'to': 'form'},
#   'accidents_accidents': {'weight': 1, 'from': 'accidents', 'to': 'accidents'},
#   'body_quantity': {'weight': 30, 'from': 'body', 'to': 'quantity'},
#   'body_movement': {'weight': 7, 'from': 'body', 'to': 'movement'},
#   'body_place': {'weight': 96, 'from': 'body', 'to': 'place'},
#   'place forasmuch_centre': {'weight': 8,
#    'from': 'place forasmuch',
#    'to': 'centre'},
#   'place forasmuch_motion': {'weight': 8,
#    'from': 'place forasmuch',
#    'to': 'motion'},
#   'place forasmuch_body': {'weight': 8,
#    'from': 'place forasmuch',
#    'to': 'body'},
#   'place forasmuch_place': {'weight': 8,
#    'from': 'place forasmuch',
#    'to': 'place'},
#   'body lines_body': {'weight': 4, 'from': 'body lines', 'to': 'body'},
#   'body lines_place': {'weight': 4, 'from': 'body lines', 'to': 'place'},
#   'form body_term': {'weight': 1, 'from': 'form body', 'to': 'term'},
#   'form body_quantity': {'weight': 1, 'from': 'form body', 'to': 'quantity'},
#   'form body_figure': {'weight': 1, 'from': 'form body', 'to': 'figure'},
#   'hast_things': {'weight': 35, 'from': 'hast', 'to': 'things'},
#   'hast_measure': {'weight': 12, 'from': 'hast', 'to': 'measure'},
#   'opinion_Avicenna': {'weight': 2, 'from': 'opinion', 'to': 'Avicenna'},
#   'opinion_subject': {'weight': 4, 'from': 'opinion', 'to': 'subject'},
#   'multitude_existence': {'weight': 3, 'from': 'multitude', 'to': 'existence'},
#   'multitude_infinity': {'weight': 3, 'from': 'multitude', 'to': 'infinity'},
#   'generation_medium': {'weight': 3, 'from': 'generation', 'to': 'medium'},
#   'existence_work': {'weight': 3, 'from': 'existence', 'to': 'work'},
#   'existence_soul': {'weight': 3, 'from': 'existence', 'to': 'soul'},
#   'existence_multitude': {'weight': 3, 'from': 'existence', 'to': 'multitude'},
#   'existence_carpenter': {'weight': 3, 'from': 'existence', 'to': 'carpenter'},
#   'existence_example': {'weight': 3, 'from': 'existence', 'to': 'example'},
#   'existence_hand': {'weight': 3, 'from': 'existence', 'to': 'hand'},
#   'things_number': {'weight': 9, 'from': 'things', 'to': 'number'},
#   'things_causes': {'weight': 52, 'from': 'things', 'to': 'causes'},
#   'multitude_little': {'weight': 5, 'from': 'multitude', 'to': 'little'},
#   'multitude_way': {'weight': 6, 'from': 'multitude', 'to': 'way'},
#   'multitude_accident': {'weight': 5, 'from': 'multitude', 'to': 'accident'},
#   'multitude_hammers': {'weight': 5, 'from': 'multitude', 'to': 'hammers'},
#   'multitude_time': {'weight': 5, 'from': 'multitude', 'to': 'time'},
#   'kind_multitude': {'weight': 6, 'from': 'kind', 'to': 'multitude'},
#   'kind_species': {'weight': 5, 'from': 'kind', 'to': 'species'},
#   'species_multitude': {'weight': 1, 'from': 'species', 'to': 'multitude'},
#   'species_species': {'weight': 11, 'from': 'species', 'to': 'species'},
#   'species_number': {'weight': 3, 'from': 'species', 'to': 'number'},
#   'species_Creator': {'weight': 3, 'from': 'species', 'to': 'Creator'},
#   'species_nature': {'weight': 12, 'from': 'species', 'to': 'nature'},
#   'species_intention': {'weight': 3, 'from': 'species', 'to': 'intention'},
#   'agent_multitude': {'weight': 4, 'from': 'agent', 'to': 'multitude'},
#   'agent_number': {'weight': 4, 'from': 'agent', 'to': 'number'},
#   'multitude increase_multitude': {'weight': 2,
#    'from': 'multitude increase',
#    'to': 'multitude'},
#   'multitude increase_magnitude': {'weight': 2,
#    'from': 'multitude increase',
#    'to': 'magnitude'},
#   'multitude increase_division': {'weight': 2,
#    'from': 'multitude increase',
#    'to': 'division'},
#   'number_things': {'weight': 15, 'from': 'number', 'to': 'things'},
#   'infinite_continuous': {'weight': 4, 'from': 'infinite', 'to': 'continuous'},
#   'infinite_division': {'weight': 4, 'from': 'infinite', 'to': 'division'},
#   'infinite_multitude': {'weight': 4, 'from': 'infinite', 'to': 'multitude'},
#   'infinite_article': {'weight': 4, 'from': 'infinite', 'to': 'article'},
#   'infinite_rule': {'weight': 4, 'from': 'infinite', 'to': 'rule'},
#   'infinite_addition': {'weight': 4, 'from': 'infinite', 'to': 'addition'},
#   'thing God_things': {'weight': 6, 'from': 'thing God', 'to': 'things'},
#   'thing God_Isaiah': {'weight': 2, 'from': 'thing God', 'to': 'Isaiah'},
#   'hast_Vulgate': {'weight': 1, 'from': 'hast', 'to': 'Vulgate'},
#   'hast_works': {'weight': 1, 'from': 'hast', 'to': 'works'},
#   'God agent_things': {'weight': 6, 'from': 'God agent', 'to': 'things'},
#   'God agent_power': {'weight': 6, 'from': 'God agent', 'to': 'power'},
#   'God agent_Phys': {'weight': 6, 'from': 'God agent', 'to': 'Phys'},
#   'God agent_accident': {'weight': 6, 'from': 'God agent', 'to': 'accident'},
#   'God agent_essence': {'weight': 6, 'from': 'God agent', 'to': 'essence'},
#   'God agent_agent': {'weight': 6, 'from': 'God agent', 'to': 'agent'},
#   'thing God_fire': {'weight': 4, 'from': 'thing God', 'to': 'fire'},
#   'thing God_essence': {'weight': 4, 'from': 'thing God', 'to': 'essence'},
#   'God_air': {'weight': 4, 'from': 'God', 'to': 'air'},
#   'God_sun': {'weight': 19, 'from': 'God', 'to': 'sun'},
#   'God_effect': {'weight': 51, 'from': 'God', 'to': 'effect'},
#   'air thing God_things': {'weight': 5,
#    'from': 'air thing God',
#    'to': 'things'},
#   'air thing God_respect': {'weight': 5,
#    'from': 'air thing God',
#    'to': 'respect'},
#   'air thing God_mode': {'weight': 5, 'from': 'air thing God', 'to': 'mode'},
#   'air thing God_I:7:1': {'weight': 5, 'from': 'air thing God', 'to': 'I:7:1'},
#   'air thing God_thing': {'weight': 5, 'from': 'air thing God', 'to': 'thing'},
#   'place_way': {'weight': 8, 'from': 'place', 'to': 'way'},
#   'place_things': {'weight': 16, 'from': 'place', 'to': 'things'},
#   'place_sense': {'weight': 2, 'from': 'place', 'to': 'sense'},
#   'place_place': {'weight': 9, 'from': 'place', 'to': 'place'},
#   'accidents_way': {'weight': 1, 'from': 'accidents', 'to': 'way'},
#   'accidents_place': {'weight': 1, 'from': 'accidents', 'to': 'place'},
#   'things_senses': {'weight': 11, 'from': 'things', 'to': 'senses'},
#   'God_existence': {'weight': 15, 'from': 'God', 'to': 'existence'},
#   'God_place': {'weight': 46, 'from': 'God', 'to': 'place'},
#   'God_presence': {'weight': 8, 'from': 'God', 'to': 'presence'},
#   'God_body': {'weight': 86, 'from': 'God', 'to': 'body'},
#   'God_fact': {'weight': 49, 'from': 'God', 'to': 'fact'},
#   'gloss_Canticles': {'weight': 1, 'from': 'gloss', 'to': 'Canticles'},
#   'gloss_Canticle': {'weight': 1, 'from': 'gloss', 'to': 'Canticle'},
#   'God_grace': {'weight': 125, 'from': 'God', 'to': 'grace'},
#   'quotation_things': {'weight': 13, 'from': 'quotation', 'to': 'things'},
#   'quotation_manner': {'weight': 3, 'from': 'quotation', 'to': 'manner'},
#   'quotation_cause': {'weight': 3, 'from': 'quotation', 'to': 'cause'},
#   'quotation_way': {'weight': 3, 'from': 'quotation', 'to': 'way'},
#   'quotation_ways': {'weight': 3, 'from': 'quotation', 'to': 'ways'},
#   'quotation_Gregory': {'weight': 3, 'from': 'quotation', 'to': 'Gregory'},
#   'quotation_Ezech': {'weight': 3, 'from': 'quotation', 'to': 'Ezech'},
#   'quotation_thing': {'weight': 3, 'from': 'quotation', 'to': 'thing'},
#   'object_operation': {'weight': 11, 'from': 'object', 'to': 'operation'},
#   'object_soul': {'weight': 12, 'from': 'object', 'to': 'soul'},
#   'object_operator': {'weight': 11, 'from': 'object', 'to': 'operator'},
#   'object_operations': {'weight': 7, 'from': 'object', 'to': 'operations'},
#   'God_creature': {'weight': 80, 'from': 'God', 'to': 'creature'},
#   'creature_affairs': {'weight': 5, 'from': 'creature', 'to': 'affairs'},
#   'creature_kingdom': {'weight': 5, 'from': 'creature', 'to': 'kingdom'},
#   'creature_things': {'weight': 30, 'from': 'creature', 'to': 'things'},
#   'creature_prerogative': {'weight': 5,
#    'from': 'creature',
#    'to': 'prerogative'},
#   'creature_presence': {'weight': 5, 'from': 'creature', 'to': 'presence'},
#   'creature_power': {'weight': 29, 'from': 'creature', 'to': 'power'},
#   'creature_substance': {'weight': 5, 'from': 'creature', 'to': 'substance'},
#   'creature_example': {'weight': 5, 'from': 'creature', 'to': 'example'},
#   'creature_way': {'weight': 37, 'from': 'creature', 'to': 'way'},
#   'creature_inspection': {'weight': 5, 'from': 'creature', 'to': 'inspection'},
#   'creature_saints': {'weight': 5, 'from': 'creature', 'to': 'saints'},
#   'creature_place': {'weight': 5, 'from': 'creature', 'to': 'place'},
#   'creature_grace': {'weight': 23, 'from': 'creature', 'to': 'grace'},
#   'creature_house': {'weight': 5, 'from': 'creature', 'to': 'house'},
#   'substance things_power': {'weight': 1,
#    'from': 'substance things',
#    'to': 'power'},
#   'things God_principle': {'weight': 1,
#    'from': 'things God',
#    'to': 'principle'},
#   'things God_power': {'weight': 4, 'from': 'things God', 'to': 'power'},
#   'things God_things': {'weight': 3, 'from': 'things God', 'to': 'things'},
#   'things_poles': {'weight': 6, 'from': 'things', 'to': 'poles'},
#   'things_power': {'weight': 57, 'from': 'things', 'to': 'power'},
#   'things_etc': {'weight': 7, 'from': 'things', 'to': 'etc'},
#   'things_person': {'weight': 10, 'from': 'things', 'to': 'person'},
#   'things_heavens': {'weight': 6, 'from': 'things', 'to': 'heavens'},
#   'things_creatures': {'weight': 15, 'from': 'things', 'to': 'creatures'},
#   'things_essence': {'weight': 25, 'from': 'things', 'to': 'essence'},
#   'things_providence': {'weight': 11, 'from': 'things', 'to': 'providence'},
#   'Ambrose_Ghost': {'weight': 5, 'from': 'Ambrose', 'to': 'Ghost'},
#   'Ambrose_God': {'weight': 27, 'from': 'Ambrose', 'to': 'God'},
#   'Ambrose_divinity': {'weight': 5, 'from': 'Ambrose', 'to': 'divinity'},
#   ...}}

# %%
df_graph["nodes"]
# Out:
# {'Scripture': {'type': 'subject', 'weight': 641},
#  'God': {'type': 'object', 'weight': 24653},
#  'justice': {'type': 'object', 'weight': 2928},
#  'end': {'type': 'object', 'weight': 4818},
#  'grasp': {'type': 'object', 'weight': 17},
#  'reason': {'type': 'object', 'weight': 12194},
#  'salvation': {'type': 'object', 'weight': 1004},
#  'science': {'type': 'object', 'weight': 553},
#  'hath': {'type': 'subject', 'weight': 1906},
#  'Thee': {'type': 'object', 'weight': 238},
#  'things': {'type': 'object', 'weight': 18133},
#  'Thou hast': {'type': 'subject', 'weight': 69},
#  'truths': {'type': 'object', 'weight': 91},
#  'thoughts': {'type': 'object', 'weight': 271},
#  'men': {'type': 'object', 'weight': 5486},
#  'man': {'type': 'object', 'weight': 37296},
#  'revelation': {'type': 'object', 'weight': 407},
#  'truth': {'type': 'subject', 'weight': 3153},
#  'admixture': {'type': 'object', 'weight': 143},
#  'errors': {'type': 'object', 'weight': 90},
#  'time': {'type': 'object', 'weight': 2864},
#  'order': {'type': 'object', 'weight': 7806},
#  'knowledge': {'type': 'object', 'weight': 5773},
#  'Augustine Trin xiv': {'type': 'subject', 'weight': 21},
#  'doctrine': {'type': 'object', 'weight': 632},
#  'faith': {'type': 'object', 'weight': 4111},
#  'principle': {'type': 'object', 'weight': 2406},
#  'mind': {'type': 'object', 'weight': 2756},
#  'sciences': {'type': 'object', 'weight': 207},
#  'arithmetic': {'type': 'object', 'weight': 5},
#  'intelligence': {'type': 'object', 'weight': 253},
#  'geometry': {'type': 'object', 'weight': 17},
#  'light': {'type': 'object', 'weight': 1246},
#  'principles': {'type': 'object', 'weight': 1786},
#  'proceeds': {'type': 'object', 'weight': 84},
#  'musician': {'type': 'subject', 'weight': 1},
#  'authority': {'type': 'object', 'weight': 1907},
#  'mathematician': {'type': 'object', 'weight': 3},
#  'Wisdom': {'type': 'subject', 'weight': 216},
#  'doctrine unity': {'type': 'subject', 'weight': 10},
#  'object': {'type': 'object', 'weight': 3782},
#  'aspect': {'type': 'object', 'weight': 664},
#  'formality': {'type': 'object', 'weight': 22},
#  'faculty': {'type': 'object', 'weight': 637},
#  'example': {'type': 'object', 'weight': 579},
#  'man stone': {'type': 'subject', 'weight': 2},
#  'color Scripture': {'type': 'subject', 'weight': 24},
#  'sight': {'type': 'object', 'weight': 908},
#  'doctrine handiwork': {'type': 'subject', 'weight': 1},
#  'doctrine God': {'type': 'subject', 'weight': 30},
#  'bliss': {'type': 'object', 'weight': 104},
#  'Objections': {'type': 'object', 'weight': 382},
#  'acts': {'type': 'object', 'weight': 2474},
#  'maids': {'type': 'object', 'weight': 6},
#  'tower': {'type': 'object', 'weight': 6},
#  'matter': {'type': 'object', 'weight': 4105},
#  'certitude': {'type': 'object', 'weight': 109},
#  'worth': {'type': 'object', 'weight': 46},
#  'respects': {'type': 'object', 'weight': 182},
#  'point': {'type': 'object', 'weight': 1280},
#  'sublimity': {'type': 'object', 'weight': 5},
#  'chiefly': {'type': 'object', 'weight': 168},
#  'purpose': {'type': 'object', 'weight': 1299},
#  'army': {'type': 'object', 'weight': 52},
#  'State': {'type': 'object', 'weight': 32},
#  'good': {'type': 'object', 'weight': 6103},
#  'standpoint': {'type': 'object', 'weight': 45},
#  'building': {'type': 'object', 'weight': 47},
#  'laborers': {'type': 'object', 'weight': 8},
#  'form': {'type': 'object', 'weight': 4838},
#  'wood': {'type': 'object', 'weight': 191},
#  'wisdom': {'type': 'object', 'weight': 1149},
#  'opposition': {'type': 'object', 'weight': 456},
#  'house': {'type': 'object', 'weight': 511},
#  'stones': {'type': 'subject', 'weight': 89},
#  'life': {'type': 'object', 'weight': 5120},
#  'architect': {'type': 'object', 'weight': 57},
#  'foundation': {'type': 'object', 'weight': 94},
#  'cause': {'type': 'object', 'weight': 3953},
#  'universe': {'type': 'object', 'weight': 210},
#  'Augustine': {'type': 'subject', 'weight': 10795},
#  'creatures': {'type': 'object', 'weight': 1275},
#  'Trin': {'type': 'object', 'weight': 299},
#  'philosophers': {'type': 'subject', 'weight': 630},
#  'treatment': {'type': 'subject', 'weight': 19},
#  'treating': {'type': 'object', 'weight': 36},
#  'God relation': {'type': 'subject', 'weight': 2},
#  'habit': {'type': 'object', 'weight': 1561},
#  'beginning': {'type': 'object', 'weight': 635},
#  'God articles object': {'type': 'subject', 'weight': 55},
#  'head': {'type': 'object', 'weight': 540},
#  'reference': {'type': 'object', 'weight': 797},
#  'Scripture bishop': {'type': 'subject', 'weight': 18},
#  'word': {'type': 'object', 'weight': 2313},
#  'gainsayers': {'type': 'object', 'weight': 17},
#  'proof': {'type': 'object', 'weight': 381},
#  'Apostle': {'type': 'subject', 'weight': 5526},
#  'regard': {'type': 'object', 'weight': 2219},
#  'resurrection': {'type': 'object', 'weight': 786},
#  'Christ': {'type': 'object', 'weight': 12201},
#  'highest': {'type': 'object', 'weight': 26},
#  'metaphysics': {'type': 'subject', 'weight': 2},
#  'opponent': {'type': 'subject', 'weight': 50},
#  'objections': {'type': 'object', 'weight': 283},
#  'dispute': {'type': 'object', 'weight': 7},
#  'concession': {'type': 'object', 'weight': 2},
#  'heretics': {'type': 'object', 'weight': 299},
#  'texts': {'type': 'object', 'weight': 4},
#  'article': {'type': 'object', 'weight': 179},
#  'Writ': {'type': 'object', 'weight': 244},
#  'articles': {'type': 'object', 'weight': 195},
#  'arguments': {'type': 'subject', 'weight': 176},
#  'comparisons': {'type': 'object', 'weight': 19},
#  'means': {'type': 'object', 'weight': 1758},
#  'metaphors': {'type': 'object', 'weight': 3},
#  'likeness': {'type': 'object', 'weight': 1073},
#  'objects': {'type': 'object', 'weight': 876},
#  'sense': {'type': 'object', 'weight': 2956},
#  'capacity': {'type': 'object', 'weight': 140},
#  'nature': {'type': 'object', 'weight': 9549},
#  'Dionysius': {'type': 'subject', 'weight': 1904},
#  'wise': {'type': 'object', 'weight': 62},
#  'covering': {'type': 'object', 'weight': 10},
#  'veils': {'type': 'object', 'weight': 14},
#  'figures': {'type': 'object', 'weight': 87},
#  'unwise': {'type': 'object', 'weight': 34},
#  'distinction': {'type': 'object', 'weight': 2181},
#  'persons': {'type': 'object', 'weight': 1606},
#  'rays': {'type': 'object', 'weight': 30},
#  'simple': {'type': 'subject', 'weight': 21},
#  'Gregory xx': {'type': 'subject', 'weight': 25},
#  'manner': {'type': 'object', 'weight': 2818},
#  'speech': {'type': 'object', 'weight': 221},
#  'fact': {'type': 'object', 'weight': 1682},
#  'mystery': {'type': 'object', 'weight': 331},
#  'author': {'type': 'subject', 'weight': 113},
#  'meaning': {'type': 'object', 'weight': 243},
#  'words': {'type': 'object', 'weight': 3576},
#  'science things': {'type': 'subject', 'weight': 3},
#  'signification': {'type': 'object', 'weight': 1132},
#  'property': {'type': 'object', 'weight': 542},
#  'signification words': {'type': 'subject', 'weight': 4},
#  'literal': {'type': 'object', 'weight': 4},
#  'sense Apostle': {'type': 'subject', 'weight': 2},
#  'Hebrews': {'type': 'object', 'weight': 305},
#  'division': {'type': 'object', 'weight': 347},
#  'Law Dionysius': {'type': 'subject', 'weight': 1},
#  'Law': {'type': 'object', 'weight': 3538},
#  'Law Head': {'type': 'subject', 'weight': 2},
#  'glory': {'type': 'object', 'weight': 1921},
#  'sense author': {'type': 'subject', 'weight': 15},
#  'intellect': {'type': 'object', 'weight': 6261},
#  'act': {'type': 'object', 'weight': 5492},
#  'God fool': {'type': 'subject', 'weight': 2},
#  'heart': {'type': 'object', 'weight': 1129},
#  'God thing': {'type': 'subject', 'weight': 73},
#  'ways': {'type': 'object', 'weight': 4429},
#  'evident': {'type': 'object', 'weight': 47},
#  'hand': {'type': 'object', 'weight': 2410},
#  'proposition': {'type': 'subject', 'weight': 153},
#  'essence': {'type': 'object', 'weight': 1925},
#  'subject': {'type': 'object', 'weight': 1345},
#  'Man': {'type': 'subject', 'weight': 900},
#  'animal': {'type': 'object', 'weight': 565},
#  'predicate': {'type': 'object', 'weight': 58},
#  'proposition terms essence proposition': {'type': 'subject', 'weight': 12},
#  'demonstration': {'type': 'object', 'weight': 116},
#  'Boethius title substances': {'type': 'subject', 'weight': 2},
#  'space': {'type': 'object', 'weight': 174},
#  'proposition God': {'type': 'subject', 'weight': 3},
#  'I:3:4': {'type': 'object', 'weight': 30},
#  'effects': {'type': 'object', 'weight': 970},
#  'thing': {'type': 'object', 'weight': 8598},
#  'effect': {'type': 'object', 'weight': 2342},
#  'effect cause': {'type': 'subject', 'weight': 52},
#  'way things thing': {'type': 'subject', 'weight': 30},
#  'fire': {'type': 'object', 'weight': 2230},
#  'senses': {'type': 'object', 'weight': 1082},
#  'motion': {'type': 'object', 'weight': 411},
#  'reduction': {'type': 'object', 'weight': 8},
#  'potentiality': {'type': 'object', 'weight': 862},
#  'state': {'type': 'object', 'weight': 2898},
#  'actuality': {'type': 'object', 'weight': 81},
#  'world': {'type': 'object', 'weight': 1698},
#  'respect': {'type': 'object', 'weight': 3233},
#  'way': {'type': 'object', 'weight': 7152},
#  'infinity': {'type': 'object', 'weight': 158},
#  'movers staff': {'type': 'subject', 'weight': 12},
#  'inasmuch': {'type': 'object', 'weight': 1200},
#  'mover': {'type': 'object', 'weight': 375},
#  'causes': {'type': 'object', 'weight': 1008},
#  'intermediate cause': {'type': 'subject', 'weight': 108},
#  'possibility': {'type': 'object', 'weight': 47},
#  'existence': {'type': 'object', 'weight': 831},
#  'beings existence thing': {'type': 'subject', 'weight': 42},
#  'necessity': {'type': 'object', 'weight': 1251},
#  'gradation': {'type': 'object', 'weight': 9},
#  'Metaph': {'type': 'object', 'weight': 227},
#  'beings': {'type': 'object', 'weight': 696},
#  'maximum cause': {'type': 'subject', 'weight': 8},
#  'governance': {'type': 'object', 'weight': 36},
#  'genus': {'type': 'object', 'weight': 790},
#  'acting': {'type': 'object', 'weight': 40},
#  'bodies': {'type': 'object', 'weight': 2222},
#  'archer': {'type': 'object', 'weight': 49},
#  'mark': {'type': 'object', 'weight': 57},
#  'result': {'type': 'object', 'weight': 759},
#  'body': {'type': 'subject', 'weight': 7499},
#  'induction': {'type': 'object', 'weight': 1},
#  'God body continuous God God body': {'type': 'subject', 'weight': 10},
#  'bodies animation': {'type': 'subject', 'weight': 1},
#  'soul': {'type': 'object', 'weight': 8312},
#  'animation': {'type': 'object', 'weight': 22},
#  'Article': {'type': 'object', 'weight': 2196},
#  'I:2:3': {'type': 'object', 'weight': 24},
#  'perfection': {'type': 'object', 'weight': 4109},
#  'God good': {'type': 'subject', 'weight': 16},
#  'agent': {'type': 'subject', 'weight': 1571},
#  'manner God': {'type': 'subject', 'weight': 3},
#  'relation': {'type': 'subject', 'weight': 1959},
#  'Godhead': {'type': 'object', 'weight': 760},
#  'suppositum': {'type': 'object', 'weight': 171},
#  'definition': {'type': 'object', 'weight': 579},
#  'species': {'type': 'object', 'weight': 3118},
#  'humanity': {'type': 'subject', 'weight': 171},
#  'man humanity man': {'type': 'subject', 'weight': 24},
#  'flesh': {'type': 'object', 'weight': 1663},
#  'accidents': {'type': 'object', 'weight': 273},
#  'thing humanity': {'type': 'subject', 'weight': 42},
#  'constituent': {'type': 'object', 'weight': 6},
#  'individualization': {'type': 'subject', 'weight': 2},
#  'forms': {'type': 'object', 'weight': 1274},
#  'supposita': {'type': 'object', 'weight': 50},
#  'Hilary': {'type': 'subject', 'weight': 246},
#  'laughing': {'type': 'object', 'weight': 10},
#  'water': {'type': 'object', 'weight': 819},
#  'thing existence': {'type': 'subject', 'weight': 6},
#  'goodness': {'type': 'object', 'weight': 1346},
#  'essence God': {'type': 'subject', 'weight': 8},
#  'participation': {'type': 'object', 'weight': 442},
#  'quantity': {'type': 'object', 'weight': 1059},
#  'concretion': {'type': 'object', 'weight': 5},
#  'actuality argument': {'type': 'subject', 'weight': 8},
#  'existence God': {'type': 'subject', 'weight': 10},
#  'essential': {'type': 'object', 'weight': 19},
#  'Philosopher': {'type': 'subject', 'weight': 4127},
#  'differences': {'type': 'object', 'weight': 97},
#  'difference God': {'type': 'subject', 'weight': 70},
#  'horse': {'type': 'object', 'weight': 73},
#  'quiddity': {'type': 'object', 'weight': 147},
#  'member': {'type': 'object', 'weight': 161},
#  'God mean God principle': {'type': 'subject', 'weight': 5},
#  'point God': {'type': 'subject', 'weight': 3},
#  'accident God form Boethius': {'type': 'subject', 'weight': 40},
#  'God Boethius': {'type': 'subject', 'weight': 1},
#  'Hebdom': {'type': 'object', 'weight': 1},
#  'essence substance': {'type': 'subject', 'weight': 4},
#  'whiteness': {'type': 'object', 'weight': 140},
#  'heat God capability': {'type': 'subject', 'weight': 14},
#  'heat': {'type': 'object', 'weight': 517},
#  'Augustine Trin God': {'type': 'subject', 'weight': 18},
#  'parts': {'type': 'object', 'weight': 1252},
#  'question': {'type': 'object', 'weight': 890},
#  'composition': {'type': 'object', 'weight': 151},
#  'God composite God': {'type': 'subject', 'weight': 2},
#  'composite': {'type': 'subject', 'weight': 59},
#  'foot': {'type': 'object', 'weight': 89},
#  'wholes': {'type': 'object', 'weight': 4},
#  'air': {'type': 'object', 'weight': 514},
#  'instance': {'type': 'object', 'weight': 2609},
#  'volume': {'type': 'subject', 'weight': 12},
#  'white': {'type': 'object', 'weight': 46},
#  'God Hilary': {'type': 'subject', 'weight': 12},
#  'argument': {'type': 'object', 'weight': 179},
#  'Dionysius cause': {'type': 'subject', 'weight': 5},
#  'opinion': {'type': 'object', 'weight': 2352},
#  'heaven': {'type': 'object', 'weight': 1432},
#  'God error': {'type': 'subject', 'weight': 4},
#  'David': {'type': 'object', 'weight': 328},
#  'Almaricians': {'type': 'object', 'weight': 1},
#  'Dinant': {'type': 'object', 'weight': 1},
#  'formal': {'type': 'object', 'weight': 7},
#  'God cause form': {'type': 'subject', 'weight': 2},
#  'matter God': {'type': 'subject', 'weight': 6},
#  'composite hand': {'type': 'subject', 'weight': 4},
#  'God potentiality form': {'type': 'subject', 'weight': 5},
#  'foregoing': {'type': 'object', 'weight': 51},
#  'compound': {'type': 'object', 'weight': 5},
#  'participates fire': {'type': 'subject', 'weight': 6},
#  'Lord': {'type': 'subject', 'weight': 5638},
#  'desirableness': {'type': 'object', 'weight': 9},
#  'like': {'type': 'object', 'weight': 670},
#  'agent God aspect': {'type': 'subject', 'weight': 6},
#  'iv': {'type': 'subject', 'weight': 635},
#  'Trinity': {'type': 'subject', 'weight': 375},
#  'minds': {'type': 'object', 'weight': 238},
#  'inasmuch perfections': {'type': 'subject', 'weight': 30},
#  'I:4:2': {'type': 'object', 'weight': 26},
#  'sun': {'type': 'object', 'weight': 640},
#  'Boethius things': {'type': 'subject', 'weight': 24},
#  'constitution': {'type': 'object', 'weight': 25},
#  'operation': {'type': 'object', 'weight': 1499},
#  'attaining': {'type': 'object', 'weight': 9},
#  'place': {'type': 'object', 'weight': 2803},
#  'creature': {'type': 'object', 'weight': 1827},
#  'I:3:6': {'type': 'object', 'weight': 4},
#  'denomination': {'type': 'object', 'weight': 9},
#  'measure': {'type': 'object', 'weight': 771},
#  'opinions Plato': {'type': 'subject', 'weight': 63},
#  'idea': {'type': 'object', 'weight': 587},
#  'ideas': {'type': 'object', 'weight': 150},
#  'subsisting': {'type': 'object', 'weight': 7},
#  'Aristotle': {'type': 'subject', 'weight': 538},
#  'assimilation': {'type': 'object', 'weight': 27},
#  'similitude': {'type': 'object', 'weight': 318},
#  'exemplary': {'type': 'object', 'weight': 7},
#  'I:4:3': {'type': 'object', 'weight': 10},
#  'Augustine Doctr': {'type': 'subject', 'weight': 409},
#  'Goodness': {'type': 'subject', 'weight': 4},
#  'Philosopher Goodness thing': {'type': 'subject', 'weight': 2},
#  'thing things': {'type': 'subject', 'weight': 21},
#  'creature God': {'type': 'subject', 'weight': 5},
#  'sort': {'type': 'object', 'weight': 114},
#  'desirability': {'type': 'object', 'weight': 5},
#  'sake': {'type': 'object', 'weight': 958},
#  'goodness things': {'type': 'subject', 'weight': 2},
#  'action': {'type': 'subject', 'weight': 3389},
#  'form converse': {'type': 'subject', 'weight': 3},
#  'power': {'type': 'subject', 'weight': 8346},
#  'Augustine Nat': {'type': 'subject', 'weight': 2},
#  'mode': {'type': 'object', 'weight': 1449},
#  'God things things essence': {'type': 'subject', 'weight': 3},
#  '1': {'type': 'object', 'weight': 127},
#  'precedes': {'type': 'object', 'weight': 199},
#  'determination': {'type': 'object', 'weight': 115},
#  'definitions': {'type': 'object', 'weight': 30},
#  'numbers': {'type': 'object', 'weight': 108},
#  'unit': {'type': 'subject', 'weight': 6},
#  'number': {'type': 'object', 'weight': 933},
#  'difference': {'type': 'subject', 'weight': 1841},
#  'inclination': {'type': 'object', 'weight': 869},
#  'weight': {'type': 'object', 'weight': 133},
#  'accordance': {'type': 'object', 'weight': 471},
#  'honestum': {'type': 'subject', 'weight': 6},
#  'fitting': {'type': 'object', 'weight': 5},
#  'contrary': {'type': 'object', 'weight': 932},
#  'Ambrose': {'type': 'subject', 'weight': 1394},
#  'use': {'type': 'object', 'weight': 2639},
#  'view': {'type': 'object', 'weight': 581},
#  'movement': {'type': 'object', 'weight': 3362},
#  'consideration': {'type': 'object', 'weight': 780},
#  'appetite': {'type': 'object', 'weight': 1865},
#  'rest': {'type': 'object', 'weight': 316},
#  'virtuous': {'type': 'object', 'weight': 21},
#  'terminates': {'type': 'subject', 'weight': 51},
#  'Father Philosopher philosophers': {'type': 'subject', 'weight': 3},
#  'reason philosophers principle': {'type': 'subject', 'weight': 1},
#  'principle God principle': {'type': 'subject', 'weight': 18},
#  'proportion': {'type': 'object', 'weight': 420},
#  'Dionysius God': {'type': 'subject', 'weight': 326},
#  'perfections': {'type': 'subject', 'weight': 218},
#  'Commentator': {'type': 'subject', 'weight': 19},
#  'considerations': {'type': 'object', 'weight': 46},
#  'man reproduces': {'type': 'subject', 'weight': 6},
#  'degree': {'type': 'object', 'weight': 1307},
#  'matter agent': {'type': 'subject', 'weight': 9},
#  'imperfect': {'type': 'object', 'weight': 100},
#  'God perfections': {'type': 'subject', 'weight': 9},
#  'line': {'type': 'object', 'weight': 96},
#  'virtue': {'type': 'object', 'weight': 4640},
#  'fashion': {'type': 'object', 'weight': 242},
#  'limitation': {'type': 'object', 'weight': 4},
#  'analogy': {'type': 'object', 'weight': 12},
#  'Damascene God philosophers': {'type': 'subject', 'weight': 15},
#  'infinitude': {'type': 'object', 'weight': 13},
#  'consequence': {'type': 'object', 'weight': 438},
#  'infinite': {'type': 'subject', 'weight': 135},
#  'Reply': {'type': 'object', 'weight': 701},
#  'Objection': {'type': 'object', 'weight': 1051},
#  'Phys': {'type': 'object', 'weight': 153},
#  'Things': {'type': 'subject', 'weight': 148},
#  'shapes': {'type': 'object', 'weight': 38},
#  'things forms': {'type': 'subject', 'weight': 8},
#  'case': {'type': 'subject', 'weight': 1955},
#  'angels': {'type': 'object', 'weight': 3392},
#  'body surface bodies': {'type': 'subject', 'weight': 20},
#  'surface': {'type': 'object', 'weight': 94},
#  'magnitude': {'type': 'object', 'weight': 108},
#  'premises': {'type': 'object', 'weight': 32},
#  'individuality': {'type': 'object', 'weight': 16},
#  'place forasmuch': {'type': 'subject', 'weight': 32},
#  'centre': {'type': 'object', 'weight': 49},
#  'body lines': {'type': 'subject', 'weight': 8},
#  'form body': {'type': 'subject', 'weight': 3},
#  'term': {'type': 'object', 'weight': 694},
#  'figure': {'type': 'object', 'weight': 314},
#  'hast': {'type': 'subject', 'weight': 904},
#  'Avicenna': {'type': 'object', 'weight': 119},
#  'multitude': {'type': 'subject', 'weight': 356},
#  'generation': {'type': 'subject', 'weight': 1128},
#  'medium': {'type': 'object', 'weight': 258},
#  'work': {'type': 'object', 'weight': 1286},
#  'carpenter': {'type': 'object', 'weight': 10},
#  'little': {'type': 'object', 'weight': 132},
#  'accident': {'type': 'object', 'weight': 214},
#  'hammers': {'type': 'object', 'weight': 5},
#  'kind': {'type': 'subject', 'weight': 2455},
#  'Creator': {'type': 'object', 'weight': 170},
#  'intention': {'type': 'object', 'weight': 1559},
#  'multitude increase': {'type': 'subject', 'weight': 6},
#  'continuous': {'type': 'object', 'weight': 19},
#  'rule': {'type': 'object', 'weight': 633},
#  'addition': {'type': 'object', 'weight': 404},
#  'thing God': {'type': 'subject', 'weight': 41},
#  'Isaiah': {'type': 'object', 'weight': 251},
#  'Vulgate': {'type': 'object', 'weight': 226},
#  'works': {'type': 'object', 'weight': 1627},
#  'God agent': {'type': 'subject', 'weight': 36},
#  'air thing God': {'type': 'subject', 'weight': 25},
#  'I:7:1': {'type': 'object', 'weight': 12},
#  'presence': {'type': 'object', 'weight': 374},
#  'gloss': {'type': 'subject', 'weight': 2294},
#  'Canticles': {'type': 'object', 'weight': 9},
#  'Canticle': {'type': 'object', 'weight': 4},
#  'grace': {'type': 'object', 'weight': 4149},
#  'quotation': {'type': 'subject', 'weight': 230},
#  'Gregory': {'type': 'object', 'weight': 3108},
#  'Ezech': {'type': 'object', 'weight': 80},
#  'operator': {'type': 'object', 'weight': 33},
#  'operations': {'type': 'object', 'weight': 793},
#  'affairs': {'type': 'object', 'weight': 251},
#  'kingdom': {'type': 'object', 'weight': 404},
#  'prerogative': {'type': 'object', 'weight': 17},
#  'substance': {'type': 'object', 'weight': 1521},
#  'inspection': {'type': 'object', 'weight': 5},
#  'saints': {'type': 'object', 'weight': 1115},
#  'substance things': {'type': 'subject', 'weight': 1},
#  'things God': {'type': 'subject', 'weight': 113},
#  'poles': {'type': 'object', 'weight': 9},
#  'etc': {'type': 'object', 'weight': 109},
#  'person': {'type': 'object', 'weight': 5095},
#  'heavens': {'type': 'object', 'weight': 234},
#  'providence': {'type': 'object', 'weight': 658},
#  'Ghost': {'type': 'object', 'weight': 3003},
#  'divinity': {'type': 'object', 'weight': 23},
#  'self': {'type': 'object', 'weight': 118},
#  'places': {'type': 'object', 'weight': 269},
#  'forasmuch man': {'type': 'subject', 'weight': 4},
#  'teeth': {'type': 'object', 'weight': 19},
#  'supposition': {'type': 'object', 'weight': 111},
#  'grain': {'type': 'subject', 'weight': 20},
#  'millet': {'type': 'object', 'weight': 1},
#  'blackness': {'type': 'object', 'weight': 11},
#  'I:3:7': {'type': 'object', 'weight': 13},
#  'plenitude': {'type': 'object', 'weight': 43},
#  'ancients': {'type': 'object', 'weight': 118},
#  'Nat': {'type': 'object', 'weight': 34},
#  'God creature': {'type': 'subject', 'weight': 20},
#  'production': {'type': 'subject', 'weight': 299},
#  'privation': {'type': 'object', 'weight': 210},
#  'regards': {'type': 'object', 'weight': 131},
#  'matter form': {'type': 'subject', 'weight': 4},
#  'bodies subject': {'type': 'subject', 'weight': 7},
#  'locality': {'type': 'object', 'weight': 8},
#  'substances': {'type': 'object', 'weight': 602},
#  'forasmuch': {'type': 'subject', 'weight': 52},
#  'kinds': {'type': 'subject', 'weight': 661},
#  'Dionysius substances': {'type': 'subject', 'weight': 46},
#  'choice': {'type': 'object', 'weight': 454},
#  'variation': {'type': 'object', 'weight': 16},
#  'evil': {'type': 'object', 'weight': 2557},
#  'Damascene': {'type': 'subject', 'weight': 857},
#  'I:8:2': {'type': 'object', 'weight': 7},
#  'powers': {'type': 'object', 'weight': 1763},
#  'creatures power God': {'type': 'subject', 'weight': 3},
#  'succession': {'type': 'subject', 'weight': 185},
#  'bereft': {'type': 'object', 'weight': 16},
#  'numbering': {'type': 'object', 'weight': 1},
#  'uniformity': {'type': 'object', 'weight': 21},
#  'apprehension': {'type': 'object', 'weight': 423},
#  'sources': {'type': 'object', 'weight': 65},
#  'eternity': {'type': 'object', 'weight': 281},
#  'Athanasius': {'type': 'subject', 'weight': 363},
#  'Creed': {'type': 'object', 'weight': 18},
#  'Father Son Ghost idea': {'type': 'subject', 'weight': 4},
#  'immutability': {'type': 'object', 'weight': 16},
#  'Jerome God': {'type': 'subject', 'weight': 50},
#  'God Eternity': {'type': 'subject', 'weight': 2},
#  'vision': {'type': 'object', 'weight': 806},
#  'corruptible': {'type': 'object', 'weight': 22},
#  'I:9:1': {'type': 'object', 'weight': 14},
#  'hills': {'type': 'object', 'weight': 12},
#  'fruits': {'type': 'object', 'weight': 222},
#  'length': {'type': 'object', 'weight': 152},
#  'Word': {'type': 'object', 'weight': 1514},
#  'duration': {'type': 'object', 'weight': 113},
#  'earth': {'type': 'object', 'weight': 800},
#  'Saints': {'type': 'object', 'weight': 32},
#  'text': {'type': 'object', 'weight': 489},
#  'Eternity time time': {'type': 'subject', 'weight': 4},
#  'eternity time': {'type': 'subject', 'weight': 4},
#  'Boethius': {'type': 'subject', 'weight': 374},
#  'Consol': {'type': 'object', 'weight': 12},
#  'v': {'type': 'subject', 'weight': 174},
#  'measures': {'type': 'object', 'weight': 21},
#  'revolution': {'type': 'object', 'weight': 4},
#  'potentialities': {'type': 'object', 'weight': 4},
#  'year': {'type': 'object', 'weight': 131},
#  'day': {'type': 'object', 'weight': 920},
#  'aeviternity': {'type': 'object', 'weight': 21},
#  'Aeviternity': {'type': 'subject', 'weight': 12},
#  'mean': {'type': 'object', 'weight': 392},
#  'eternity difference': {'type': 'subject', 'weight': 4},
#  'eternity time aeviternity theory': {'type': 'subject', 'weight': 16},
#  'contradiction': {'type': 'object', 'weight': 175},
#  'innovation': {'type': 'object', 'weight': 14},
#  'receding': {'type': 'object', 'weight': 2},
#  'incongruity': {'type': 'subject', 'weight': 30},
#  'changeableness': {'type': 'object', 'weight': 30},
#  'fact thing': {'type': 'subject', 'weight': 2},
#  'changelessness': {'type': 'object', 'weight': 1},
#  'measure eternity': {'type': 'subject', 'weight': 4},
#  'permanence': {'type': 'object', 'weight': 22},
#  'change': {'type': 'object', 'weight': 728},
#  'movements': {'type': 'subject', 'weight': 989},
#  'affections': {'type': 'object', 'weight': 443},
#  'Aeviternity time': {'type': 'subject', 'weight': 2},
#  'ells': {'type': 'object', 'weight': 3},
#  'cloth': {'type': 'object', 'weight': 19},
#  'unity durations': {'type': 'subject', 'weight': 26},
#  'unity': {'type': 'object', 'weight': 904},
#  'diversity': {'type': 'object', 'weight': 499},
#  'influx': {'type': 'object', 'weight': 14},
#  'time measure forasmuch': {'type': 'subject', 'weight': 4},
#  'reasons': {'type': 'object', 'weight': 964},
#  'reason time': {'type': 'subject', 'weight': 6},
#  'oneness': {'type': 'object', 'weight': 67},
#  'equality': {'type': 'object', 'weight': 414},
#  'Origen': {'type': 'subject', 'weight': 447},
#  'Archon': {'type': 'object', 'weight': 11},
#  'element': {'type': 'object', 'weight': 171},
#  'present': {'type': 'object', 'weight': 168},
#  'reality': {'type': 'object', 'weight': 396},
#  'undivision': {'type': 'object', 'weight': 10},
#  'indivisibility': {'type': 'object', 'weight': 25},
#  'undivided': {'type': 'subject', 'weight': 1},
#  'God reason thing': {'type': 'subject', 'weight': 1},
#  'simplicity': {'type': 'object', 'weight': 105},
#  'Socrates': {'type': 'subject', 'weight': 242},
#  'I:3:3': {'type': 'object', 'weight': 6},
#  'God Gods': {'type': 'subject', 'weight': 9},
#  'gods perfection gods philosophers': {'type': 'subject', 'weight': 50},
#  'thereto': {'type': 'object', 'weight': 411},
#  'Bernard': {'type': 'subject', 'weight': 75},
#  'subsistent': {'type': 'subject', 'weight': 12},
#  'bat': {'type': 'object', 'weight': 158},
#  'account': {'type': 'object', 'weight': 3103},
#  'excess': {'type': 'object', 'weight': 278},
#  'intellect opinion beatitude': {'type': 'subject', 'weight': 18},
#  'function': {'type': 'object', 'weight': 23},
#  'beatitude': {'type': 'subject', 'weight': 542},
#  'wonder': {'type': 'object', 'weight': 72},
#  'desire': {'type': 'object', 'weight': 1005},
#  'desire blessed': {'type': 'subject', 'weight': 6},
#  'glass': {'type': 'object', 'weight': 39},
#  'enigma': {'type': 'object', 'weight': 6},
#  'seer': {'type': 'object', 'weight': 45},
#  'similitude substance principle': {'type': 'subject', 'weight': 6},
#  'eye': {'type': 'object', 'weight': 309},
#  'stone': {'type': 'object', 'weight': 212},
#  'similitudes': {'type': 'object', 'weight': 51},
#  'Psalm': {'type': 'object', 'weight': 549},
#  'organ': {'type': 'object', 'weight': 221},
#  'I:3:1': {'type': 'object', 'weight': 2},
#  'grace life': {'type': 'subject', 'weight': 19},
#  'knower': {'type': 'object', 'weight': 113},
#  'knowledge mode': {'type': 'subject', 'weight': 72},
#  'natures': {'type': 'object', 'weight': 507},
#  'singular': {'type': 'object', 'weight': 69},
#  'therefrom': {'type': 'object', 'weight': 169},
#  'creature intellect': {'type': 'subject', 'weight': 4},
#  'disposition': {'type': 'object', 'weight': 1562},
#  'height': {'type': 'object', 'weight': 80},
#  'understanding': {'type': 'object', 'weight': 1026},
#  'Apocalypse': {'type': 'object', 'weight': 65},
#  'illumination': {'type': 'object', 'weight': 17},
#  'saying': {'type': 'object', 'weight': 447},
#  'John': {'type': 'object', 'weight': 869},
#  'Star': {'type': 'subject', 'weight': 12},
#  'star': {'type': 'object', 'weight': 361},
#  'intellect faculty': {'type': 'subject', 'weight': 64},
#  'deiformity': {'type': 'object', 'weight': 8},
#  'intellect desire': {'type': 'subject', 'weight': 64},
#  'apt': {'type': 'object', 'weight': 8},
#  'charity': {'type': 'object', 'weight': 3054},
#  'answer': {'type': 'subject', 'weight': 129},
#  'counsel': {'type': 'object', 'weight': 605},
#  'thought': {'type': 'object', 'weight': 302},
#  'hosts': {'type': 'object', 'weight': 33},
#  'Verb': {'type': 'object', 'weight': 37},
#  'triangle': {'type': 'subject', 'weight': 37},
#  'angles': {'type': 'object', 'weight': 68},
#  'God intellect': {'type': 'subject', 'weight': 34},
#  'ignorance': {'type': 'object', 'weight': 775},
#  'whosoever': {'type': 'subject', 'weight': 111},
#  'things effects': {'type': 'subject', 'weight': 36},
#  'conclusions': {'type': 'object', 'weight': 337},
#  'intellect God God': {'type': 'subject', 'weight': 3},
#  'image': {'type': 'object', 'weight': 625},
#  'glance': {'type': 'object', 'weight': 135},
#  'whereof': {'type': 'object', 'weight': 161},
#  'Man gloss': {'type': 'subject', 'weight': 30},
#  'images': {'type': 'object', 'weight': 216},
#  'reason mode': {'type': 'subject', 'weight': 8},
#  'I:2:9': {'type': 'object', 'weight': 4},
#  'dreams': {'type': 'object', 'weight': 74},
#  'events': {'type': 'object', 'weight': 543},
#  'supreme': {'type': 'object', 'weight': 6},
#  'relationship creatures': {'type': 'subject', 'weight': 16},
#  'defect': {'type': 'object', 'weight': 748},
#  'Apostle hath': {'type': 'subject', 'weight': 27},
#  'princes': {'type': 'object', 'weight': 232},
#  'spirit': {'type': 'object', 'weight': 858},
#  'infusion': {'type': 'object', 'weight': 163},
#  'imagination': {'type': 'object', 'weight': 320},
#  'visions': {'type': 'object', 'weight': 44},
#  'Baptism': {'type': 'object', 'weight': 1414},
#  'dove': {'type': 'object', 'weight': 182},
#  'conceptions': {'type': 'object', 'weight': 36},
#  'shape': {'type': 'object', 'weight': 128},
#  'Father': {'type': 'object', 'weight': 1591},
#  'Lord Almighty': {'type': 'subject', 'weight': 4},
#  'war': {'type': 'object', 'weight': 145},
#  'conception': {'type': 'object', 'weight': 414},
#  'I:12:11': {'type': 'object', 'weight': 12},
#  'excellence': {'type': 'object', 'weight': 577},
#  'names': {'type': 'subject', 'weight': 627},
#  'remotion': {'type': 'object', 'weight': 10},
#  'distance': {'type': 'object', 'weight': 126},
#  'Moses': {'type': 'object', 'weight': 505},
#  'relationship': {'type': 'object', 'weight': 353},
#  'opinions': {'type': 'object', 'weight': 446},
#  'words God God': {'type': 'subject', 'weight': 4},
#  'matter names': {'type': 'subject', 'weight': 72},
#  'health': {'type': 'object', 'weight': 501},
#  'medicine': {'type': 'object', 'weight': 212},
#  'representation': {'type': 'object', 'weight': 100},
#  'intellects intellect': {'type': 'subject', 'weight': 4},
#  'principle effects': {'type': 'subject', 'weight': 4},
#  'creatures God meaning God': {'type': 'subject', 'weight': 1},
#  'God meaning': {'type': 'subject', 'weight': 12},
#  'Doctr': {'type': 'object', 'weight': 29},
#  'Ambrose names': {'type': 'subject', 'weight': 99},
#  'majesty': {'type': 'object', 'weight': 35},
#  'perfections intellect': {'type': 'subject', 'weight': 72},
#  'viz': {'type': 'object', 'weight': 161},
#  'synonyms united': {'type': 'subject', 'weight': 1},
#  'clothing': {'type': 'object', 'weight': 26},
#  'meanings': {'type': 'object', 'weight': 6},
#  'Articles': {'type': 'object', 'weight': 277},
#  'solution': {'type': 'object', 'weight': 87},
#  'aspects': {'type': 'object', 'weight': 79},
#  'terms': {'type': 'subject', 'weight': 592},
#  'wisdom genus': {'type': 'subject', 'weight': 3},
#  'God creatures distance': {'type': 'subject', 'weight': 1},
#  'predication': {'type': 'subject', 'weight': 55},
#  'predication reason effect': {'type': 'subject', 'weight': 50},
#  'distinct': {'type': 'object', 'weight': 27},
#  'exercise': {'type': 'object', 'weight': 204},
#  'manifold': {'type': 'object', 'weight': 14},
#  'circumscribes': {'type': 'object', 'weight': 2},
#  'reasoning': {'type': 'object', 'weight': 66},
#  'fallacy': {'type': 'object', 'weight': 8},
#  'equivocation': {'type': 'object', 'weight': 12},
#  'healthy': {'type': 'object', 'weight': 21},
#  'equivocal': {'type': 'object', 'weight': 3},
#  'mode idea term': {'type': 'subject', 'weight': 28},
#  'proportions': {'type': 'object', 'weight': 7},
#  'community': {'type': 'object', 'weight': 366},
#  'analogies': {'type': 'object', 'weight': 2},
#  'sign': {'type': 'object', 'weight': 477},
#  'equivocals': {'type': 'object', 'weight': 2},
#  'urine': {'type': 'object', 'weight': 29},
#  'univocals': {'type': 'object', 'weight': 2},
#  'animals': {'type': 'object', 'weight': 1061},
#  'field': {'type': 'object', 'weight': 49},
#  'lion': {'type': 'object', 'weight': 68},
#  'flowering': {'type': 'object', 'weight': 2},
#  'beauty': {'type': 'object', 'weight': 241},
#  'smile': {'type': 'object', 'weight': 2},
#  'strength': {'type': 'object', 'weight': 315},
#  'imposition': {'type': 'object', 'weight': 141},
#  'extremes': {'type': 'object', 'weight': 84},
#  'relation order': {'type': 'subject', 'weight': 66},
#  'relations': {'type': 'object', 'weight': 758},
#  'habitude': {'type': 'object', 'weight': 43},
#  'extreme': {'type': 'object', 'weight': 28},
#  'extremes sense': {'type': 'subject', 'weight': 12},
#  'perception': {'type': 'object', 'weight': 57},
#  'inasmuch intellect': {'type': 'subject', 'weight': 3},
#  'right': {'type': 'object', 'weight': 747},
#  'column': {'type': 'object', 'weight': 8},
#  'relation God': {'type': 'subject', 'weight': 4},
#  'creation': {'type': 'object', 'weight': 496},
#  'Ambrose God': {'type': 'subject', 'weight': 52},
#  'signifies': {'type': 'subject', 'weight': 160},
#  'properties': {'type': 'object', 'weight': 261},
#  'source': {'type': 'subject', 'weight': 213},
#  'Dionysius Deity': {'type': 'subject', 'weight': 15},
#  'courage': {'type': 'object', 'weight': 57},
#  'names form': {'type': 'subject', 'weight': 9},
#  'subjects': {'type': 'object', 'weight': 354},
#  'reason mind': {'type': 'subject', 'weight': 204},
#  'plurality': {'type': 'object', 'weight': 91},
#  'Achilles': {'type': 'object', 'weight': 12},
#  'abstraction': {'type': 'object', 'weight': 108},
#  'individuals': {'type': 'object', 'weight': 227},
#  'rules': {'type': 'subject', 'weight': 152},
#  'I:11:3': {'type': 'object', 'weight': 8},
#  'Gods': {'type': 'object', 'weight': 1},
#  'Hebrew': {'type': 'object', 'weight': 9},
#  'Tetragrammaton': {'type': 'object', 'weight': 9},
#  'Herm': {'type': 'object', 'weight': 9},
#  'picture': {'type': 'object', 'weight': 7},
#  'heathen': {'type': 'subject', 'weight': 8},
#  'idol': {'type': 'subject', 'weight': 19},
#  'Deity': {'type': 'object', 'weight': 41},
#  'Catholic': {'type': 'subject', 'weight': 30},
#  'significations': {'type': 'object', 'weight': 19},
#  'issue': {'type': 'object', 'weight': 142},
#  'god': {'type': 'object', 'weight': 54},
#  'remark': {'type': 'subject', 'weight': 31},
#  'Moses Lord thou': {'type': 'subject', 'weight': 176},
#  'universality': {'type': 'object', 'weight': 68},
#  'God names': {'type': 'subject', 'weight': 2},
#  'sea': {'type': 'object', 'weight': 118},
#  'consignification': {'type': 'object', 'weight': 9},
#  'ocean': {'type': 'object', 'weight': 14},
#  'past': {'type': 'object', 'weight': 144},
#  'propositions God': {'type': 'subject', 'weight': 12},
#  'propositions': {'type': 'object', 'weight': 73},
#  'man thing': {'type': 'subject', 'weight': 102},
#  'predicates': {'type': 'subject', 'weight': 8},
#  'identity': {'type': 'object', 'weight': 67},
#  'riches': {'type': 'object', 'weight': 286},
#  'amplitude': {'type': 'object', 'weight': 2},
#  'Philosopher soul': {'type': 'subject', 'weight': 39},
#  'contraction': {'type': 'subject', 'weight': 63},
#  'immateriality': {'type': 'subject', 'weight': 51},
#  'ii': {'type': 'object', 'weight': 797},
#  'plants sense': {'type': 'subject', 'weight': 8},
#  'iii': {'type': 'object', 'weight': 765},
#  'operation Philosopher': {'type': 'subject', 'weight': 2},
#  'sensible intelligible': {'type': 'subject', 'weight': 8},
#  'God intellect case': {'type': 'subject', 'weight': 6},
#  'Augustine God God': {'type': 'subject', 'weight': 80},
#  'I:1:2': {'type': 'object', 'weight': 6},
#  'vii': {'type': 'subject', 'weight': 286},
#  'act Philosopher': {'type': 'subject', 'weight': 12},
#  'potentiality act': {'type': 'subject', 'weight': 74},
#  'essence act': {'type': 'subject', 'weight': 6},
#  'object act': {'type': 'subject', 'weight': 39},
#  'multiplicity': {'type': 'object', 'weight': 55},
#  'subsists': {'type': 'object', 'weight': 25},
#  'eyes': {'type': 'object', 'weight': 340},
#  'mirror': {'type': 'object', 'weight': 66},
#  'joints': {'type': 'object', 'weight': 20},
#  'perfect': {'type': 'object', 'weight': 525},
#  'understanding God': {'type': 'subject', 'weight': 36},
#  'examples': {'type': 'object', 'weight': 286},
#  'lines': {'type': 'object', 'weight': 142},
#  'colors': {'type': 'object', 'weight': 99},
#  'position': {'type': 'object', 'weight': 215},
#  'causality': {'type': 'object', 'weight': 117},
#  'living': {'type': 'object', 'weight': 276},
#  'intelligent': {'type': 'object', 'weight': 16},
#  'essences': {'type': 'object', 'weight': 19},
#  'common': {'type': 'object', 'weight': 57},
#  'proper': {'type': 'object', 'weight': 13},
#  'circle': {'type': 'object', 'weight': 72},
#  'modes': {'type': 'object', 'weight': 54},
#  'God things': {'type': 'subject', 'weight': 4},
#  'particularity': {'type': 'object', 'weight': 6},
#  'discursion': {'type': 'object', 'weight': 33},
#  'unknown': {'type': 'object', 'weight': 42},
#  'second': {'type': 'subject', 'weight': 1498},
#  'discursion God': {'type': 'subject', 'weight': 8},
#  'spiritual': {'type': 'object', 'weight': 53},
#  'knowledge artificer': {'type': 'subject', 'weight': 14},
#  'art': {'type': 'object', 'weight': 573},
#  'artificer': {'type': 'object', 'weight': 33},
#  'form heat': {'type': 'subject', 'weight': 11},
#  'heating': {'type': 'object', 'weight': 185},
#  'far': {'type': 'object', 'weight': 369},
#  'inclination form inasmuch': {'type': 'subject', 'weight': 24},
#  'Philosopher God': {'type': 'subject', 'weight': 12},
#  'approbation': {'type': 'object', 'weight': 6},
#  'reason God': {'type': 'subject', 'weight': 33},
#  'future': {'type': 'object', 'weight': 380},
#  'God futurity': {'type': 'subject', 'weight': 2},
#  'Hell': {'type': 'subject', 'weight': 28},
#  'corruption God': {'type': 'subject', 'weight': 8},
#  'darkness': {'type': 'object', 'weight': 266},
#  'Empedocles': {'type': 'object', 'weight': 23},
#  'discord': {'type': 'object', 'weight': 79},
#  'universal': {'type': 'object', 'weight': 125},
#  'eclipses': {'type': 'object', 'weight': 16},
#  'astrologer': {'type': 'object', 'weight': 16},
#  'Sophroniscus': {'type': 'object', 'weight': 16},
#  'singularity': {'type': 'object', 'weight': 20},
#  'application': {'type': 'object', 'weight': 245},
#  'particular': {'type': 'object', 'weight': 73},
#  'knowledge causality power': {'type': 'subject', 'weight': 32},
#  'I:44:2': {'type': 'object', 'weight': 30},
#  'Augustine Civ': {'type': 'subject', 'weight': 300},
#  'bounds': {'type': 'object', 'weight': 116},
#  'knowledge world generation': {'type': 'subject', 'weight': 18},
#  'hearts': {'type': 'object', 'weight': 273},
#  'creatures reason': {'type': 'subject', 'weight': 36},
#  'individual': {'type': 'object', 'weight': 802},
#  'particulars': {'type': 'object', 'weight': 21},
#  'reason species essence intellect': {'type': 'subject', 'weight': 60},
#  'works God': {'type': 'subject', 'weight': 12},
#  'evidence': {'type': 'object', 'weight': 244},
#  'contingent': {'type': 'object', 'weight': 23},
#  'I:10:2': {'type': 'object', 'weight': 2},
#  'types': {'type': 'object', 'weight': 150},
#  'presentiality': {'type': 'object', 'weight': 10},
#  'antecedent': {'type': 'subject', 'weight': 38},
#  'antecedent Philosopher': {'type': 'subject', 'weight': 8},
#  'objection': {'type': 'object', 'weight': 77},
#  'thing distinction': {'type': 'subject', 'weight': 12},
#  'crow': {'type': 'subject', 'weight': 8},
#  'objection words': {'type': 'subject', 'weight': 84},
#  'enunciations': {'type': 'object', 'weight': 33},
#  'forthwith': {'type': 'subject', 'weight': 128},
#  'enunciation': {'type': 'object', 'weight': 21},
#  'knowledge substance': {'type': 'subject', 'weight': 6},
#  'knowledge Philosopher': {'type': 'subject', 'weight': 6},
#  'Metaphysics': {'type': 'object', 'weight': 28},
#  'builder': {'type': 'subject', 'weight': 233},
#  'speculative': {'type': 'object', 'weight': 34},
#  'end builder': {'type': 'subject', 'weight': 50},
#  'period': {'type': 'object', 'weight': 35},
#  'sicknesses': {'type': 'subject', 'weight': 30},
#  'physician': {'type': 'object', 'weight': 487},
#  'nobility': {'type': 'object', 'weight': 16},
#  'Augustine xlvi),"Such': {'type': 'subject', 'weight': 12},
#  'Idea': {'type': 'subject', 'weight': 15},
#  'forma': {'type': 'object', 'weight': 2},
#  'chance': {'type': 'object', 'weight': 146},
#  'ends': {'type': 'object', 'weight': 156},
#  'form agent': {'type': 'subject', 'weight': 4},
#  'agents': {'type': 'object', 'weight': 150},
#  'notion': {'type': 'subject', 'weight': 634},
#  'Augustine Ideas': {'type': 'subject', 'weight': 36},
#  'end order good': {'type': 'subject', 'weight': 6},
#  'general': {'type': 'object', 'weight': 34},
#  'type': {'type': 'object', 'weight': 335},
#  'imitation': {'type': 'object', 'weight': 30},
#  'Ideas': {'type': 'subject', 'weight': 2},
#  'Plato': {'type': 'object', 'weight': 257},
#  'office': {'type': 'object', 'weight': 540},
#  'exemplar': {'type': 'object', 'weight': 108},
#  'making': {'type': 'object', 'weight': 25},
#  'appetite intellect': {'type': 'subject', 'weight': 2},
#  'knowledge thing': {'type': 'subject', 'weight': 2},
#  'appetite desirer': {'type': 'subject', 'weight': 3},
#  'object true': {'type': 'subject', 'weight': 6},
#  'true': {'type': 'object', 'weight': 58},
#  'pass': {'type': 'subject', 'weight': 7},
#  'preconception': {'type': 'object', 'weight': 12},
#  'Augustine Truth Hilary Truth': {'type': 'subject', 'weight': 20},
#  'Truth viii truth': {'type': 'subject', 'weight': 6},
#  'unlikeness': {'type': 'object', 'weight': 22},
#  'conformity': {'type': 'object', 'weight': 129},
#  'comparison': {'type': 'object', 'weight': 576},
#  'Truth': {'type': 'subject', 'weight': 143},
#  'soul good good': {'type': 'subject', 'weight': 3},
#  'desirable': {'type': 'object', 'weight': 1},
#  'mathematics': {'type': 'object', 'weight': 8},
#  'true regards nature': {'type': 'subject', 'weight': 3},
#  'regards good': {'type': 'subject', 'weight': 1},
#  'truth things': {'type': 'subject', 'weight': 40},
#  'children': {'type': 'object', 'weight': 2390},
#  'face': {'type': 'object', 'weight': 213},
#  'intellects': {'type': 'object', 'weight': 79},
#  'entity': {'type': 'object', 'weight': 2},
#  'essences truth': {'type': 'subject', 'weight': 3},
#  'I:10:3': {'type': 'object', 'weight': 2},
#  'intellect truth intellect truth': {'type': 'subject', 'weight': 1},
#  'God truth': {'type': 'subject', 'weight': 1},
#  'false': {'type': 'object', 'weight': 4},
#  'truth intellect': {'type': 'subject', 'weight': 8},
#  'falsity': {'type': 'object', 'weight': 82},
#  'Augustine body': {'type': 'subject', 'weight': 17},
#  'falsity opposites': {'type': 'subject', 'weight': 36},
#  'se': {'type': 'object', 'weight': 76},
#  'ordinance': {'type': 'object', 'weight': 111},
#  'human': {'type': 'object', 'weight': 189},
#  'vanity': {'type': 'object', 'weight': 87},
#  'quality': {'type': 'object', 'weight': 344},
#  'Scriptures': {'type': 'object', 'weight': 179},
#  'deeds': {'type': 'object', 'weight': 585},
#  'sin': {'type': 'object', 'weight': 9193},
#  'diameter Philosopher Augustine tragedian': {'type': 'subject', 'weight': 35},
#  'appearances': {'type': 'object', 'weight': 11},
#  'rise': {'type': 'object', 'weight': 109},
#  'gall Augustine': {'type': 'subject', 'weight': 6},
#  'occasion': {'type': 'object', 'weight': 120},
#  'resemblance': {'type': 'subject', 'weight': 64},
#  'instances': {'type': 'object', 'weight': 68},
#  'majority': {'type': 'object', 'weight': 129},
#  'Augustine senses': {'type': 'subject', 'weight': 8},
#  'error': {'type': 'object', 'weight': 490},
#  'Falsity': {'type': 'subject', 'weight': 3},
#  'truth senses': {'type': 'subject', 'weight': 36},
#  'I:16:2': {'type': 'object', 'weight': 6},
#  'apprehending': {'type': 'object', 'weight': 2},
#  'knowledge likeness': {'type': 'subject', 'weight': 108},
#  'indisposition': {'type': 'object', 'weight': 138},
#  'sweet': {'type': 'object', 'weight': 14},
#  'impressions': {'type': 'object', 'weight': 73},
#  'judgment': {'type': 'object', 'weight': 2202},
#  'composition truth': {'type': 'subject', 'weight': 2},
#  'qualities': {'type': 'object', 'weight': 324},
#  'feet': {'type': 'object', 'weight': 217},
#  'sensible': {'type': 'object', 'weight': 73},
#  'affirming': {'type': 'object', 'weight': 7},
#  'sensibles': {'type': 'object', 'weight': 58},
#  'judging': {'type': 'object', 'weight': 166},
#  'intellect falsity': {'type': 'subject', 'weight': 24},
#  'statement animals intellect': {'type': 'subject', 'weight': 3},
#  'Philosopher opinion': {'type': 'subject', 'weight': 15},
#  'affirmation': {'type': 'object', 'weight': 109},
#  'contraries': {'type': 'object', 'weight': 123},
#  'negation': {'type': 'subject', 'weight': 184},
#  'blindness': {'type': 'object', 'weight': 108},
#  'Contraries': {'type': 'subject', 'weight': 8},
#  'color': {'type': 'object', 'weight': 181},
#  'Philosopher iv': {'type': 'subject', 'weight': 9},
#  'plants': {'type': 'object', 'weight': 138},
#  'life bodies': {'type': 'subject', 'weight': 6},
#  'things life': {'type': 'subject', 'weight': 59},
#  'Vegetab': {'type': 'object', 'weight': 2},
#  'animal movement': {'type': 'subject', 'weight': 14},
#  'cognizance': {'type': 'object', 'weight': 23},
#  'appearance': {'type': 'object', 'weight': 130},
#  'dimensions': {'type': 'object', 'weight': 105},
#  'abstract': {'type': 'object', 'weight': 74},
#  'Philosopher ix': {'type': 'subject', 'weight': 8},
#  'Life': {'type': 'subject', 'weight': 41},
#  'executing': {'type': 'object', 'weight': 3},
#  'instrument': {'type': 'object', 'weight': 276},
#  'growth': {'type': 'object', 'weight': 96},
#  'animals principle': {'type': 'subject', 'weight': 4},
#  'perfect movement': {'type': 'subject', 'weight': 33},
#  'touch': {'type': 'object', 'weight': 339},
#  'expansion': {'type': 'object', 'weight': 36},
#  'shellfish': {'type': 'object', 'weight': 12},
#  'connection': {'type': 'object', 'weight': 348},
#  'instinct': {'type': 'object', 'weight': 146},
#  'command': {'type': 'object', 'weight': 546},
#  'organs': {'type': 'object', 'weight': 128},
#  'arts': {'type': 'object', 'weight': 52},
#  'material': {'type': 'object', 'weight': 51},
#  'navigation': {'type': 'object', 'weight': 7},
#  'ship': {'type': 'object', 'weight': 63},
#  'turn': {'type': 'object', 'weight': 8},
#  'designing': {'type': 'object', 'weight': 2},
#  'Philosopher God God': {'type': 'subject', 'weight': 2},
#  'thing act': {'type': 'subject', 'weight': 8},
#  'wherefore things things': {'type': 'subject', 'weight': 2},
#  'things intellect': {'type': 'subject', 'weight': 84},
#  'aptitude': {'type': 'object', 'weight': 160},
#  'intellectual': {'type': 'object', 'weight': 17},
#  'pertain': {'type': 'object', 'weight': 79},
#  'Apostle Ephesians': {'type': 'subject', 'weight': 80},
#  'man subject': {'type': 'subject', 'weight': 2},
#  'number Socrates': {'type': 'subject', 'weight': 64},
#  'divine': {'type': 'object', 'weight': 24},
#  'happiness': {'type': 'object', 'weight': 1279},
#  'food': {'type': 'object', 'weight': 747},
#  'journey': {'type': 'object', 'weight': 49},
#  'perfection things': {'type': 'subject', 'weight': 10},
#  'Thou': {'type': 'subject', 'weight': 814},
#  'ii agent means': {'type': 'subject', 'weight': 4},
#  'arrow': {'type': 'object', 'weight': 46},
#  'character': {'type': 'object', 'weight': 715},
#  'acts agent': {'type': 'subject', 'weight': 20},
#  'inclination intellect': {'type': 'subject', 'weight': 4},
#  'appertains': {'type': 'object', 'weight': 2},
#  'Augustine lxxxiii cause': {'type': 'subject', 'weight': 72},
#  'premiss': {'type': 'object', 'weight': 5},
#  'conclusion': {'type': 'object', 'weight': 139},
#  'premisses': {'type': 'object', 'weight': 9},
#  'thing thinker premisses': {'type': 'subject', 'weight': 2},
#  'ordering': {'type': 'object', 'weight': 143},
#  'rule thing': {'type': 'subject', 'weight': 3},
#  'hindrance': {'type': 'object', 'weight': 77},
#  ...}

# %%
df_graph["edges"]
